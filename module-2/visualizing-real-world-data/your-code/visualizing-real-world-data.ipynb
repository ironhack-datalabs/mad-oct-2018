# %%
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
apple_store = pd.read_csv('AppleStore.csv')
apple_store.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
apple_des = pd.read_csv('appleStore_description.csv')
apple_des.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#                                             app_desc
# 0  SAVE 20%, now only $3.99 for a limited time!\n...
# 1  Let Evernote change the way you organize your ...
# 2  Download the most popular free weather app pow...
# 3  The eBay app is the best way to find anything ...
# 4  On more than 250 million devices around the wo...

# %%
# Unimos los dos dataframe 
df = pd.merge(apple_store, apple_des, how='left', on='id').drop(['track_name_y', 'size_bytes_y'], axis=1)
df.head()
# Out:
#    Unnamed: 0         id                                       track_name_x  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes_x currency  price  rating_count_tot  rating_count_ver  \
# 0     100788224      USD   3.99             21292                26
# 1     158578688      USD   0.00            161065                26
# 2     100524032      USD   0.00            188583              2822
# 3     128512000      USD   0.00            262241               649
# 4      92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 0 to 7196
# Data columns (total 18 columns):
# Unnamed: 0          7197 non-null int64
# id                  7197 non-null int64
# track_name_x        7197 non-null object
# size_bytes_x        7197 non-null int64
# currency            7197 non-null object
# price               7197 non-null float64
# rating_count_tot    7197 non-null int64
# rating_count_ver    7197 non-null int64
# user_rating         7197 non-null float64
# user_rating_ver     7197 non-null float64
# ver                 7197 non-null object
# cont_rating         7197 non-null object
# prime_genre         7197 non-null object
# sup_devices.num     7197 non-null int64
# ipadSc_urls.num     7197 non-null int64
# lang.num            7197 non-null int64
# vpp_lic             7197 non-null int64
# app_desc            7197 non-null object
# dtypes: float64(3), int64(9), object(6)
# memory usage: 1.0+ MB

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
df.corr()
# Out:
#                   Unnamed: 0        id  size_bytes_x     price  \
# Unnamed: 0          1.000000  0.910714      0.041277 -0.074326
# id                  0.910714  1.000000      0.077486 -0.075247
# size_bytes_x        0.041277  0.077486      1.000000  0.182392
# price              -0.074326 -0.075247      0.182392  1.000000
# rating_count_tot   -0.168640 -0.201976      0.004486 -0.039044
# rating_count_ver   -0.064717 -0.072784      0.006337 -0.018012
# user_rating        -0.204867 -0.185178      0.066256  0.046601
# user_rating_ver    -0.127580 -0.109849      0.086075  0.025173
# sup_devices.num     0.024648  0.033605     -0.118347 -0.115361
# ipadSc_urls.num     0.014589  0.052082      0.152697  0.066100
# lang.num           -0.148487 -0.128932      0.004614 -0.006713
# vpp_lic             0.000501  0.017743     -0.150418 -0.029942
#
#                   rating_count_tot  rating_count_ver  user_rating  \
# Unnamed: 0               -0.168640         -0.064717    -0.204867
# ...

# %%
df['price'].describe()
# Out:
# count    7197.000000
# mean        1.726218
# std         5.833006
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.990000
# max       299.990000
# Name: price, dtype: float64

# %%
# Distribución de price
a = sns.distplot(df['price'], bins=10, kde=True)
a

# %%
# Histogramas 
bins = [0,1,3,5,10,20]
fig, axes = plt.subplots(1,3, figsize=(12,6))
axes[0].hist(df['size_bytes_x'], bins=10)
axes[1].hist(df['user_rating'], bins=10)
axes[2].hist(df['price'], bins=bins)
axes[0].set_title('App size')
axes[1].set_title('User rating')
axes[2].set_title('Price')
# Out:
# Text(0.5, 1.0, 'Price')

# %%
# Scatter plot 
ax1 = df.plot(kind='scatter', x='user_rating_ver', y='price', color='r')    
ax1

# %%
# Scatter plot 
ax1 = df.plot(kind='scatter', x='user_rating_ver', y='price', color='r', label='user_rating_ver')    
ax2 = df.plot(kind='scatter', x='user_rating', y='price', color='g', ax=ax1, label='user_rating')   
print(ax1 == ax2)
# Out:
# True

# %%
# Distribución del rating y del rating por versión de cada género
df2 = df[['user_rating', 'user_rating_ver', 'prime_genre']].groupby(['prime_genre']).agg("mean")
df2.plot.bar()

# %%
# Violin plot
sns.violinplot(x='prime_genre', y='user_rating', data=df)
#pivot table
# Out:
# /home/miriam/.local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pd.plotting.scatter_matrix(df[['price', 'user_rating', 'user_rating_ver']])
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd923371358>,
# ...
#       dtype=object)
