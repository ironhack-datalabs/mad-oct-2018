# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
print('')
print('Printing a few head and tail rows')
display(titanic.head())
display(titanic.tail())
# Out:
# Printing a few head and tail rows
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
display(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
info=titanic.describe(include='all').T
info['type']=titanic.dtypes
print('')
print('** I prefer this kind of description with its dtypes **')
print('')
print('')
print('Data Frame General Info')
display(info)
# Out:
# ** I prefer this kind of description with its dtypes **
#
#
# Data Frame General Info
#             count unique               top  freq      mean       std   min  \
# PassengerId  1309    NaN               NaN   NaN       655    378.02     1
# Survived      891    NaN               NaN   NaN  0.383838  0.486592     0
# Pclass       1309    NaN               NaN   NaN   2.29488  0.837836     1
# Name         1309   1307  Kelly, Mr. James     2       NaN       NaN   NaN
# Gender       1309      2              male   843       NaN       NaN   NaN
# Age          1309    NaN               NaN   NaN   29.8792   13.4483  0.17
# SibSp        1309    NaN               NaN   NaN  0.498854   1.04166     0
# Parch        1309    NaN               NaN   NaN  0.385027   0.86556     0
# Ticket       1309    929          CA. 2343    11       NaN       NaN   NaN
# Fare         1309    NaN               NaN   NaN   33.2811   51.7415     0
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
num_titanic=titanic.select_dtypes(include=['float64','int64','float32','int32']).head()
counter=0
for item in num_titanic.columns.tolist():
    if counter==0:
        print('Numerical variables:')
        counter+=1
    print(' >> ',item)
# Out:
# Numerical variables:
#  >>  PassengerId
#  >>  Survived
#  >>  Pclass
#  >>  Age
#  >>  SibSp
#  >>  Parch
#  >>  Fare

# %%
#your code here- categorical variable
num_titanic=titanic.select_dtypes(include='object').head()
counter=0
for item in num_titanic.columns.tolist():
    if counter==0:
        print('Categorical variables:')
        counter+=1
    print(' >> ',item)
# Out:
# Categorical variables:
#  >>  Name
#  >>  Gender
#  >>  Ticket
#  >>  Cabin
#  >>  Embarked

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.rcParams['figure.figsize'] = [8.0, 6.0]
plt.style.use('classic')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
fig,ax=plt.subplots(2,1)
titanic['Age'].hist(ax=ax[0]) 
titanic['Age'].hist(bins=range(0,int(max(titanic['Age']))+1,10),ax=ax[1])

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig,ax=plt.subplots(3,1)

titanic['Age'].hist(bins=10,ax=ax[0]) 
titanic['Age'].hist(bins=20,ax=ax[1]) 
titanic['Age'].hist(bins=50,ax=ax[2])

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
# Because it has to distribute the frequencies in different sizes of bins. For many bins, it reduces the width of 
# columns to properly addapt the size of the bins. All bins have to have the same width. 
# The main effect, for many bins, we have lower peaks of frequencies than for low number of bins. I think its better
# to define de bin width with a range statement. For exmaple, if we want bins with a width of 10 years starting 
# at 0 years, the best code would be (as far as I know) bins=range(0,int(max(titanic['Age']))+1,10)

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'].values,kde=True)
# If you use titanic['Age'] without specifying that we want the values, it will deliver an warning message that 
# even being a pandas series, working fine right now, it wont be taken as a series due to its index.
# Remember this for the futuuuuureeee or Fry wont be able to get out from the cryogenic capsule!
# Out:
# /home/ivan/.local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot(kind='bar')
ax=plt.gca()
ax.xaxis.set_tick_params(rotation=0)

# %%
# your code here- 2nd way
sns.countplot(titanic['Gender'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
# Pclass is int64 format, but it is distributed from 1 to 3, so best visualization would be bar plot
sns.countplot(titanic['Pclass'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic.boxplot(column='Age',return_type='axes')
plt.axhline(y=titanic['Age'].mean(),color='blue',label='Mean %s' %round(titanic['Age'].mean(),1),linestyle='--')
plt.axhline(y=titanic['Age'].quantile(0.5),color='red',label='Median %s' %titanic['Age'].quantile(0.5),linestyle='--')
plt.axhline(y=titanic['Age'].quantile(0.75),color='gold',label='3rd quartile %s' %titanic['Age'].quantile(0.75),linestyle='-')
plt.axhline(y=titanic['Age'].quantile(0.25),color='green',label='1st quartile %s' %titanic['Age'].quantile(0.25),linestyle='-')

plt.legend(fontsize=10)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
# The boxplot give us many information: Median, 1st and 3rd quartiles, the IQR (Inter Quartile Ratio) which is
# defined as the distance between the 1st and 3rd Quartiles, and the Whiskers. The whiskers are 1.5 times the IQR
# and beyond this whiskers data is taken as Outliers

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.kdeplot(titanic['Age'], label='AGE',shade=True)
IQR=titanic['Age'].quantile(0.75)-titanic['Age'].quantile(0.25)
IQRplus=round(titanic['Age'].quantile(0.75)+1.5*IQR,1)
IQRminus=round(titanic['Age'].quantile(0.25)-1.5*IQR,1)
plt.axvline(x=titanic['Age'].mean(),color='blue',label='Mean %s' %round(titanic['Age'].mean(),1),linestyle='--')
plt.axvline(x=titanic['Age'].quantile(0.5),color='red',label='Median %s' %titanic['Age'].quantile(0.5),linestyle='--')
plt.axvline(x=titanic['Age'].quantile(0.75),color='gold',label='3rd quartile %s' %titanic['Age'].quantile(0.75),linestyle='-')
plt.axvline(x=titanic['Age'].quantile(0.25),color='green',label='1st quartile %s' %titanic['Age'].quantile(0.25),linestyle='-')
plt.axvline(x=IQRplus,color='magenta',label='Upper Whisker %s' %IQRplus,linestyle='-')
plt.axvline(x=IQRminus,color='black',label='Lowe Whisker %s' %IQRminus,linestyle='-')
plt.legend(fontsize=10)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# We return the probability density curve for the distribution. This return us how different ages and 
# its probability density on the distribution.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
# Seaborn way
sns.relplot(x="Age", y="Fare", data=titanic)

# %%
# your code-2nd way
titanic.plot(x='Age',y='Fare',kind='scatter')

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
plt.figure(1)
corr = titanic.corr()
colormap = plt.cm.plasma_r
sns.heatmap(corr, cmap=colormap, annot=True, fmt=".2f")

plt.xticks(np.arange(len(corr.columns))+0.5, corr.columns);
plt.yticks(np.arange(len(corr.columns))+0.5, corr.columns)
ax=plt.gca()
ax.xaxis.set_tick_params(rotation=45)
ax.set_title('Pearson Correlation Coeficients')

plt.figure(2)
corr = titanic.corr(method='spearman')
colormap = plt.cm.plasma_r
sns.heatmap(corr, cmap=colormap, annot=True, fmt=".2f")

plt.xticks(np.arange(len(corr.columns))+0.5, corr.columns);
plt.yticks(np.arange(len(corr.columns))+0.5, corr.columns)
ax=plt.gca()
ax.xaxis.set_tick_params(rotation=45)
ax.set_title('Spearman Correlation Coeficients')
# Out:
# Text(0.5, 1.0, 'Spearman Correlation Coeficients')

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
# The most correlated Features are Pclass with Fare with a -0.56 Pearson Correlation Coeficient
# I have analyzed them too with Spearman Correlation and Fare and Pclass are the features with more coeficient -0.71

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g=sns.FacetGrid(titanic,col='Gender')
g.map(plt.hist, "Age")

# %% [markdown]
# ___
