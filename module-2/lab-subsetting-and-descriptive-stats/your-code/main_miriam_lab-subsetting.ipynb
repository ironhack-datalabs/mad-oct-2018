# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()
#Podemos comprobar que tenemos 7 registros, con 3 columnas donde City y State sson de tipo object. 
# La columna Temperature es de tipo float64.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
# City           7 non-null object
# State          7 non-null object
# Temperature    7 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
a = temp[temp['State'] == 'New York']
a
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
Tem_ny_mean= a['Temperature'].mean()
Tem_ny_mean
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp['City'][temp.Temperature > 15]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
condition =(temp.Temperature > 15) & (temp.Temperature < 20)
display(temp[condition]['City'])
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
#temp2=temp.set_index([temp["State"], temp.index])
#temp2
tem_state_mean = temp.groupby('State', as_index=False).agg({'Temperature':['mean', 'std']})
display (tem_state_mean)
# Out:
#          State Temperature
#                       mean       std
# 0  Connecticut   15.833333  1.964186
# 1   New Jersey   21.111111  1.571348
# 2     New York   10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv('Employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()
#Existen 5 registros tipo objeto y 2 registros tipo int64.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
# Name          9 non-null object
# Department    9 non-null object
# Education     9 non-null object
# Gender        9 non-null object
# Title         9 non-null object
# Years         9 non-null int64
# Salary        9 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 584.0+ bytes

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# %matplotlib inline
employee.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ca8469be0>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employee[employee['Salary'] == employee['Salary'].min()]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee['Name'] == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee['Name'] == 'David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
employee[employee['Title'] == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee_group = employee.groupby('Years', as_index=False).agg({'Salary':['mean']})
display (employee_group)
# Out:
#   Years     Salary
#               mean
# 0     1  35.000000
# 1     2  38.333333
# 2     3  55.000000
# 3     4  35.000000
# 4     7  60.000000
# 5     8  70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
employee_group_2 = employee.groupby('Title', as_index=False).agg({'Salary':'mean'})
employee_group_2
# Out:
#        Title     Salary
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
employee.boxplot()

# %%
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
salary_gender = employee.groupby('Gender', as_index=False).agg({'Salary': 'mean'})
salary_gender
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
group_department_2 = employee.groupby('Department', as_index=False).agg({'Salary': ['min', 'mean', 'max'], 
                                                                     'Years': ['min', 'mean', 'max']})
group_department
# Out:
#   Department Salary            Years
#                 min   mean max   min      mean max
# 0         HR     30  45.00  70     2  4.666667   8
# 1         IT     30  48.75  70     1  4.500000   8
# 2      Sales     55  55.00  55     2  2.500000   3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
group_department2 = employee.groupby('Department', as_index=False)
min_dep = group_department2['Salary'].min()
max_dep = group_department2['Salary'].max()
new_dep = pd.merge(min_dep, max_dep, on='Department')
new_dep2 = new_dep['Salary_y'] - new_dep['Salary_x']
new_dep2
# Out:
# 0    40
# 1    40
# 2     0
# dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# 5                5     536365     22752  2010     12    3     8
# 6                6     536365     21730  2010     12    3     8
# 7                7     536366     22633  2010     12    3     8
# 8                8     536366     22632  2010     12    3     8
# 9                9     536367     84879  2010     12    3     8
# 10              10     536367     22745  2010     12    3     8
# 11              11     536367     22748  2010     12    3     8
# 12              12     536367     22749  2010     12    3     8
# 13              13     536367     22310  2010     12    3     8
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
type(orders)
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
# Unnamed: 0      397924 non-null int64
# InvoiceNo       397924 non-null int64
# StockCode       397924 non-null object
# year            397924 non-null int64
# month           397924 non-null int64
# day             397924 non-null int64
# hour            397924 non-null int64
# Description     397924 non-null object
# Quantity        397924 non-null int64
# InvoiceDate     397924 non-null object
# UnitPrice       397924 non-null float64
# CustomerID      397924 non-null int64
# Country         397924 non-null object
# amount_spent    397924 non-null float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders['UnitPrice'].mean()
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %%
orders['UnitPrice'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
orders_id_unique = orders.set_index(['CustomerID'])
orders_id_unique[orders_id_unique['Country'] == 'Spain']
# Out:
#             Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# CustomerID
# 12557             6421     536944     22383  2010     12    5    12
# 12557             6422     536944     22384  2010     12    5    12
# 12557             6423     536944     20727  2010     12    5    12
# 12557             6424     536944     20725  2010     12    5    12
# 12557             6425     536944     20728  2010     12    5    12
# 17097            21565     538095     22504  2010     12    4    14
# 17097            21566     538095     22212  2010     12    4    14
# 17097            21567     538095     22953  2010     12    4    14
# 17097            21568     538095     84818  2010     12    4    14
# 17097            21569     538095     21114  2010     12    4    14
# 17097            21570     538095     84692  2010     12    4    14
# 17097            21571     538095     22796  2010     12    4    14
# 17097            21572     538095     40001  2010     12    4    14
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
(orders['Country'] == 'Spain').sum()
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
customer_orders = orders.groupby('CustomerID', as_index=False).agg({'Quantity' : sum})
customer_orders[customer_orders['Quantity'] > 50]
# Out:
#       CustomerID  Quantity
# 0          12346     74215
# 1          12347      2458
# 2          12348      2341
# 3          12349       631
# 4          12350       197
# 5          12352       536
# 7          12354       530
# 8          12355       240
# 9          12356      1591
# 10         12357      2708
# 11         12358       248
# 12         12359      1622
# 13         12360      1165
# 14         12361        91
# 15         12362      2229
# 16         12363       408
# 17         12364      1506
# 18         12365       174
# 19         12367       173
# 20         12370      2353
# 21         12371       591
# 22         12372       794
# 23         12373       197
# 24         12374       342
# 25         12375       178
# 26         12377       944
# 27         12378      2529
# 28         12379       407
# 29         12380      1127
# 30         12381       808
# ...          ...       ...
# 4307       18240       126
# 4308       18241      1051
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders[(orders['Country'] == 'Spain') & (orders['Quantity'] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders[orders['Quantity'] == 3]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 15              15     536367     22623  2010     12    3     8
# 17              17     536367     21754  2010     12    3     8
# 18              18     536367     21755  2010     12    3     8
# 22              22     536368     22913  2010     12    3     8
# 23              23     536368     22912  2010     12    3     8
# 24              24     536368     22914  2010     12    3     8
# 25              25     536369     21756  2010     12    3     8
# 45              45     536370      POST  2010     12    3     8
# 117            117     536381     21169  2010     12    3     9
# 125            125     536381     71270  2010     12    3     9
# 138            138     536381     22778  2010     12    3     9
# 153            155     536384     82484  2010     12    3     9
# 163            165     536384     22427  2010     12    3     9
# 181            183     536388     21754  2010     12    3     9
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders[orders['Quantity'] == 3]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
orders[orders['Description'].str.contains('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# 361            370     536401     20726  2010     12    3    11
# 362            371     536401     22384  2010     12    3    11
# 402            411     536404     22383  2010     12    3    11
# 403            412     536404     20728  2010     12    3    11
# 404            413     536404     20727  2010     12    3    11
# 532            541     536412     20728  2010     12    3    11
# 533            542     536412     22382  2010     12    3    11
# 535            544     536412     22662  2010     12    3    11
# 536            545     536412     22383  2010     12    3    11
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
orders_spain = orders[orders['Country'] == 'Spain']['amount_spent']
orders_spain.hist()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
orders_august = orders[orders['month'] == 8]
orders_august
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# 199480      285426     561905     84978  2011      8    1     9
# 199481      285427     561905     21754  2011      8    1     9
# 199482      285428     561905     23226  2011      8    1     9
# 199483      285429     561905     21715  2011      8    1     9
# 199484      285430     561905     21716  2011      8    1     9
# 199485      285431     561905     21746  2011      8    1     9
# 199486      285432     561905     21755  2011      8    1     9
# 199487      285433     561906     22367  2011      8    1    10
# 199488      285434     561906     20914  2011      8    1    10
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
orders_august_country = orders_august.groupby(['Country'], as_index=False).agg({'Quantity': sum})
orders_august_country
# Out:
#             Country  Quantity
# 0         Australia     12570
# 1           Austria       790
# 2           Belgium      2069
# 3            Canada        52
# 4   Channel Islands      2009
# 5           Denmark       338
# 6              EIRE      9331
# 7           Finland       693
# 8            France      7958
# 9           Germany      9641
# 10          Iceland       277
# 11           Israel      3028
# 12            Italy      1147
# 13            Malta       382
# 14      Netherlands     29876
# 15           Norway       636
# 16           Poland       186
# 17         Portugal      1026
# 18            Spain      1600
# 19           Sweden      1314
# 20      Switzerland      2998
# 21   United Kingdom    310832
# 22      Unspecified       185

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
average_country = orders.groupby('Country', as_index=False).agg({'amount_spent': 'mean'})
average_country
# Out:
#                  Country  amount_spent
# 0              Australia    116.895620
# 1                Austria     25.624824
# 2                Bahrain     32.258824
# 3                Belgium     20.283772
# 4                 Brazil     35.737500
# 5                 Canada     24.280662
# 6        Channel Islands     27.340160
# 7                 Cyprus     22.134169
# 8         Czech Republic     33.069600
# 9                Denmark     49.882474
# 10                  EIRE     36.687745
# 11    European Community     21.670833
# 12               Finland     32.913985
# 13                France     25.056827
# 14               Germany     25.311562
# 15                Greece     32.831172
# 16               Iceland     23.681319
# 17                Israel     29.119718
# 18                 Italy     23.064960
# 19                 Japan    116.561900
# 20               Lebanon     37.641778
# 21             Lithuania     47.458857
# 22                 Malta     24.335625
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
order_years_mean = orders.groupby(['year'], as_index=False).agg({'amount_spent':'mean'})
order_years_mean
# Out:
#    year  amount_spent
# 0  2010     21.892733
# 1  2011     22.430074
