# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on pokemons... You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
# import libraries

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
import dataset as ds
import numpy as np
import pandas as pd

pokemon = pd.read_csv('Pokemon.csv')

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions as follows:
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | Sum of all stats that come after this, a general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Print the distinct values in `Type 1` and `Type 2` combined

# %%
# enter your code here

pokemon_type = pokemon.groupby[("Type 1, Type 2")].size().reset_index(name=freq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-b55f3beb19b5> in <module>
#       1 # enter your code here
#       2
# ----> 3 pokemon_type = pokemon.groupby[("Type 1, Type 2")].size()
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# Check out the pokemon names in the first 10 rows. You find there are junk texts in the pokemon names which contain "Mega". For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".
#
# ### Cleanup `Name` that contain "Mega"

# %%
# enter your code here
pokemon.loc[pokemon['Name'].str.startswith('Mega'), 'Name'] = 'Mega Venusaur'
pokemon.loc[pokemon['Name'].str.startswith('Mega'), 'Name'] = 'Mega Charizard X'

# test transformed data

pokemon.head(10)


### por que me aparece name como un object cuando saco un type y cuando hago el cambio me sale como un boolean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-a8b1c98089a9> in <module>
#       1 # enter your code here
# ----> 2 pokemon.loc[pokemon['Name'].str.startswith('Mega'), 'Name'] = 'Mega Venusaur'
#       3 pokemon.loc[pokemon['Name'].str.startswith('Mega'), 'Name'] = 'Mega Charizard X'
#       4
#       5 # test transformed data
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     245                 if i >= self.obj.ndim:
#     246                     raise IndexingError('Too many indexers')
# --> 247                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     248                 keyidx.append(idx)
#     249         return tuple(keyidx)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: '[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan\n nan nan nan nan nan nan nan nan] not in index'

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, pokemon #1 has the Attack score 49 and Defense score 49. The corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
pokemon['Attack/Defense Ratio'] = pokemon['Attack']/pokemon['Defense']

# test transformed data

pokemon.head(10)
# Out:
#    # Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1    1  Grass  Poison    318  45      49       49       65       65     45
# 1  2    2  Grass  Poison    405  60      62       63       80       80     60
# 2  3    3  Grass  Poison    525  80      82       83      100      100     80
# 3  3  NaN  Grass  Poison    625  80     100      123      122      120     80
# 4  4    4   Fire     NaN    309  39      52       43       60       50     65
# 5  5    5   Fire     NaN    405  58      64       58       80       65     80
# 6  6    6   Fire  Flying    534  78      84       78      109       85    100
# 7  6  NaN   Fire  Dragon    634  78     130      111      130       85    100
# 8  6  NaN   Fire  Flying    634  78     104       78      159      115    100
# 9  7    7  Water     NaN    314  44      48       65       50       64     43
#
#    Generation  Legendary  Attack/Defense Ratio    Combo Type
# 0           1      False              1.000000  Grass-Poison
# 1           1      False              0.984127  Grass-Poison
# 2           1      False              0.987952  Grass-Poison
# 3           1      False              0.813008  Grass-Poison
# 4           1      False              1.209302          Fire
# 5           1      False              1.103448          Fire
# 6           1      False              1.076923   Fire-Flying
# 7           1      False              1.171171   Fire-Dragon
# 8           1      False              1.333333   Fire-Flying
# 9           1      False              0.738462         Water

# %% [markdown]
# ### Print the pokemon with the highest `A/D Ratio`

# %%
# enter your code here
pokemon["Attack/Defense Ratio"].max()
pokemon.loc[pokemon['Attack/Defense Ratio'] == 9.0]
# Out:
#        # Name   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 429  386  386  Psychic    NaN    600  50     180       20      180       20
#
#      Speed  Generation  Legendary  Attack/Defense Ratio
# 429    150           3       True                   9.0

# %% [markdown]
# ### Print the pokemon with the lowest A/D Ratio

# %%
# enter your code here
pokemon["Attack/Defense Ratio"].min()
pokemon.loc[pokemon['Attack/Defense Ratio'] == 0.043478260869565216]
# Out:
#        # Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  213    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  Attack/Defense Ratio
# 230      5           2      False              0.043478

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Conditions:
#
# * If `Type 2` value is a valid string, the `Combo Type` value should be `<Type 1>-<Type 2>` (e.g. `Grass-Poison`).
#
# * If `Type 2` value is `NaN`, the `Combo Type` value should be the same as `Type 1` which always exists.
#
# *Hint: Consider using function and `apply`.*

# %%
# enter your code here
  
def f(x): 
    res = x[0]
    if type(x[1]) == str: 
        res = res + '-' + x[1]
    return res

pokemon ['Combo Type'] = pokemon[['Type 1','Type 2']].apply(lambda x: f(x), axis=1)    


# test transformed data

pokemon.head(15)
# Out:
#      # Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1    1  Grass  Poison    318  45      49       49       65       65
# 1    2    2  Grass  Poison    405  60      62       63       80       80
# 2    3    3  Grass  Poison    525  80      82       83      100      100
# 3    3  NaN  Grass  Poison    625  80     100      123      122      120
# 4    4    4   Fire     NaN    309  39      52       43       60       50
# 5    5    5   Fire     NaN    405  58      64       58       80       65
# 6    6    6   Fire  Flying    534  78      84       78      109       85
# 7    6  NaN   Fire  Dragon    634  78     130      111      130       85
# 8    6  NaN   Fire  Flying    634  78     104       78      159      115
# 9    7    7  Water     NaN    314  44      48       65       50       64
# 10   8    8  Water     NaN    405  59      63       80       65       80
# 11   9    9  Water     NaN    530  79      83      100       85      105
# 12   9  NaN  Water     NaN    630  79     103      120      135      115
# 13  10   10    Bug     NaN    195  45      30       35       20       20
# 14  11   11    Bug     NaN    205  50      20       55       25       25
#
#     Speed  Generation  Legendary  Attack/Defense Ratio    Combo Type
# 0      45           1      False              1.000000  Grass-Poison
# 1      60           1      False              0.984127  Grass-Poison
# 2      80           1      False              0.987952  Grass-Poison
# 3      80           1      False              0.813008  Grass-Poison
# 4      65           1      False              1.209302          Fire
# 5      80           1      False              1.103448          Fire
# 6     100           1      False              1.076923   Fire-Flying
# 7     100           1      False              1.171171   Fire-Dragon
# 8     100           1      False              1.333333   Fire-Flying
# 9      43           1      False              0.738462         Water
# 10     58           1      False              0.787500         Water
# 11     78           1      False              0.830000         Water
# 12     78           1      False              0.858333         Water
# 13     45           1      False              0.857143           Bug
# 14     30           1      False              0.363636           Bug

# %% [markdown]
# ### Print `Combo Type` for pokemons whose `A/D Ratio` are among the top 5

# %%
head_5 = pokemon.sort_values('Attack/Defense Ratio', ascending = False)['Combo Type'].head(5)
head_5
# Out:
# 429       Psychic
# 347    Water-Dark
# 19     Bug-Poison
# 453          Rock
# 348    Water-Dark
# Name: Combo Type, dtype: object

# %% [markdown]
# ### For the 5 `Combo Type` values printed from the previous question, calculate the aggregated `Attack` scores for each `Combo Type`.

# %%
# enter your code here
pokemon.groupby(['Combo Type'])['Attack'].sum().filter(head_5)
# Out:
# Combo Type
# Psychic       2468
# Water-Dark     720
# Bug-Poison     820
# Rock           930
# Water-Dark     720
# Name: Attack, dtype: int64

# %% [markdown]
# ### `Total` formula hypothesis testing
#
# From the data descriptions you may have noticed there is a column called `Total` which indicates how strong the pokemon is. Make a hypothesis how `Total` is calculated and test your hypothesis.
#
# The general guideline is first examine the data carefully and make a guess how `Total` might have been calculated. You can write a math formula and convert it to a function. Then calculate the results based on your formula and store the results in a new column called `Guessed Total`. Next compare whether `Guessed Total` and `Total` contain the same values. If values match, congratuations you have verified your hypothesis! Otherwise, revise your formula, update the values in `Guessed Total`, and compare again.

# %%
# enter your code here
combinacion lineal de varias columnas 

pokemon["Guessed Total"]
