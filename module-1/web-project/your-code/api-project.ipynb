# %%
# api project

# https://rickandmortyapi.com/

# %%
# imports

from funciones import get_num_episodios, get_stats, create_df, save_df, flatten_list, create_df_p

# %%
# Toma de números de episodios
set_episodios = get_num_episodios()
# Out:
# Introduce números enteros entre 1 y 31 separados por coma:
# Numeros: 4,5

# %%
# Obtenemos diccionario con los personajes y sus apariciones
personajes_episodios = get_stats(set_episodios)

# %%
total_personajes = flatten_list(personajes_episodios)

# %%
df = create_df(personajes_episodios)
df
# Out:
#                                     Appereances  Appereances (%)
# Characters
# Rick Sanchez                                  2            100.0
# Beth Smith                                    2            100.0
# Jerry Smith                                   2            100.0
# Summer Smith                                  2            100.0
# Morty Smith                                   2            100.0
# Evil Jerry Clone                              1             50.0
# Tiny-persons advocacy group lawyer            1             50.0
# Tammy Guetermann                              1             50.0
# Stair Goblin                                  1             50.0
# Slippery Stair                                1             50.0
# Samantha                                      1             50.0
# Principal Vagina                              1             50.0
# Mr. Meeseeks                                  1             50.0
# Mr. Booby Buyer                               1             50.0
# King Jellybean                                1             50.0
# Evil Summer Clone                             1             50.0
# Dale                                          1             50.0
# Evil Beth Clone                               1             50.0
# Big Boobed Waitress                           1             50.0
# Stu                                           1             50.0
# Prince Nebulon                                1             50.0
# Mr. Marklovitz                                1             50.0
# Mr. Goldenfold                                1             50.0
# Kevin                                         1             50.0
# Jessica's Friend                              1             50.0
# Jessica                                       1             50.0
# Cynthia                                       1             50.0
# Giant Judge                                   1             50.0

# %%
# Guardamos el DataFrame en un archivo
save_df(df, l_epi=set_episodios)

# %%
# Mejoras futuras

# %%
df_final = create_df_p(df, personajes_episodios, total_personajes)
df_final
# Out:
#                                     Appereances  Appereances (%)  0  1
# Characters
# Rick Sanchez                                  2            100.0  1  1
# Beth Smith                                    2            100.0  1  1
# Jerry Smith                                   2            100.0  1  1
# Summer Smith                                  2            100.0  1  1
# Morty Smith                                   2            100.0  1  1
# Evil Jerry Clone                              1             50.0  0  1
# Tiny-persons advocacy group lawyer            1             50.0  0  1
# Tammy Guetermann                              1             50.0  0  1
# Stair Goblin                                  1             50.0  0  1
# Slippery Stair                                1             50.0  0  1
# Samantha                                      1             50.0  0  1
# Principal Vagina                              1             50.0  0  1
# Mr. Meeseeks                                  1             50.0  0  1
# Mr. Booby Buyer                               1             50.0  0  1
# King Jellybean                                1             50.0  0  1
# Evil Summer Clone                             1             50.0  0  1
# Dale                                          1             50.0  0  1
# Evil Beth Clone                               1             50.0  0  1
# Big Boobed Waitress                           1             50.0  0  1
# Stu                                           1             50.0  1  0
# Prince Nebulon                                1             50.0  1  0
# Mr. Marklovitz                                1             50.0  1  0
# Mr. Goldenfold                                1             50.0  1  0
# Kevin                                         1             50.0  1  0
# Jessica's Friend                              1             50.0  1  0
# Jessica                                       1             50.0  1  0
# Cynthia                                       1             50.0  1  0
# Giant Judge                                   1             50.0  0  1

# %%
# Guardamos el DataFrame en un archivo
save_df(df_final, l_epi=set_episodios)
