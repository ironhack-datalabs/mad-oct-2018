# %% [markdown]
# # Guided Project: API and Web Data Scraping
#
# ## API | Rick and Morty API

# %%
# api project

# https://rickandmortyapi.com/

# %%
# imports
from funciones import get_num_episodios, get_stats, create_df, save_df, flatten_list, create_df_p

# %% [markdown]
# ### Primera iteración

# %%
# Toma de números de episodios
set_episodios = get_num_episodios()
# Out:
# Introduce números enteros entre 1 y 31 separados por coma:
# Numeros: 6,7

# %%
# Obtenemos diccionario con los personajes y sus apariciones
personajes_episodios = get_stats(set_episodios)

# %%
total_personajes = flatten_list(personajes_episodios)

# %%
df = create_df(personajes_episodios)
df
# Out:
#                         Appereances  Appereances (%)
# Characters
# Rick Sanchez                      3            150.0
# Summer Smith                      3            150.0
# Beth Smith                        3            150.0
# Jerry Smith                       3            150.0
# Morty Smith                       3            150.0
# Davin                             2            100.0
# Principal Vagina                  1             50.0
# Veronica Ann Bennet               1             50.0
# Snuffles (Snowball)               1             50.0
# Pawnshop Clerk                    1             50.0
# Morty Jr.                         1             50.0
# Ma-Sha                            1             50.0
# Jackie                            1             50.0
# Gwendolyn                         1             50.0
# Brad Anderson                     1             50.0
# Tammy Guetermann                  1             50.0
# ...

# %%
# Guardamos el DataFrame en un archivo
save_df(df, l_epi=set_episodios)

# %% [markdown]
# ### Primera iteración

# %%
df_final = create_df_p(df, personajes_episodios, total_personajes)
df_final
# Out:
#                         Appereances  Appereances (%)  0  1
# Characters
# Rick Sanchez                      3            150.0  2  1
# Summer Smith                      3            150.0  2  1
# Beth Smith                        3            150.0  2  1
# Jerry Smith                       3            150.0  2  1
# Morty Smith                       3            150.0  2  1
# Davin                             2            100.0  2  0
# Principal Vagina                  1             50.0  1  0
# Veronica Ann Bennet               1             50.0  0  1
# Snuffles (Snowball)               1             50.0  0  1
# Pawnshop Clerk                    1             50.0  0  1
# Morty Jr.                         1             50.0  0  1
# Ma-Sha                            1             50.0  0  1
# Jackie                            1             50.0  0  1
# Gwendolyn                         1             50.0  0  1
# Brad Anderson                     1             50.0  0  1
# ...

# %%
# Guardamos el DataFrame en un archivo
save_df(df_final, l_epi=set_episodios)

# %% [markdown]
# ### Mejoras futuras

# %%
# a partir de aquí incluir las mejoras futuras

# %%
'''
1. Permitir que la toma de episodios permita un formato tal que así: 4, 5, 7-11, 12
2. Reducir el número de peticiones a la API puesto que si un personaje ya ha sido consultado para 
obtener su nombre, deberiamos almacenar la consulta para no tener que realizarla repetidas veces. 
3. Preguntar el nombre del fichero de salida para guardar los datos.
4. La columna del capítulo debería tener el número (o el nombre) de dicho capítulo y no ser: 0, 1, 2, 3 etc 
que corresponden al orden de petición. 
'''
