# %%
# api project

# https://rickandmortyapi.com/

# %%
# imports

from funciones import get_num_episodios, get_stats, create_df, save_df, flatten_list, create_df_p

# %%
# Toma de números de episodios
set_episodios = get_num_episodios()
# Out:
# Introduce números enteros entre 1 y 31 separados por coma:
# Numeros: 3,4,5,6,7,8,1,2,3,23,24

# %%
# Obtenemos diccionario con los personajes y sus apariciones
personajes_episodios = get_stats(set_episodios)

# %%
total_personajes = flatten_list(personajes_episodios)

# %%
df = create_df(personajes_episodios)
df
# Out:
#                                    Appereances  Appereances (%)
# Characters
# Rick Sanchez                                11            110.0
# Beth Smith                                  11            110.0
# Morty Smith                                 11            110.0
# Summer Smith                                11            110.0
# Jerry Smith                                 10            100.0
# Mr. Goldenfold                               5             50.0
# Principal Vagina                             4             40.0
# Davin                                        4             40.0
# Snuffles (Snowball)                          3             30.0
# Jessica                                      3             30.0
# Jessica's Friend                             3             30.0
# Trunkphobic suspenders guy                   2             20.0
# Bill                                         2             20.0
# Tammy Guetermann                             2             20.0
# Mrs. Sanchez                                 2             20.0
# Glenn                                        2             20.0
# Cynthia                                      2             20.0
# Shmlangela Shmlobinson-Shmlower              1             10.0
# Regular Legs                                 1             10.0
# Real Fake Doors Salesman                     1             10.0
# Piece of Toast                               1             10.0
# Shmlamantha Shmlicelli                       1             10.0
# Unmuscular Michael                           1             10.0
# Shmlona Shmlobinson                          1             10.0
# Shmlonathan Shmlower                         1             10.0
# Shmlony Shmlicelli                           1             10.0
# Guy from The Bachelor                        1             10.0
# Tophat Jones                                 1             10.0
# Trunk Man                                    1             10.0
# Two Guys with Handlebar Mustaches            1             10.0
# ...                                        ...              ...
# Veronica Ann Bennet                          1             10.0
# Pawnshop Clerk                               1             10.0
# Morty Jr.                                    1             10.0
# Ma-Sha                                       1             10.0
# Gwendolyn                                    1             10.0
# Brad Anderson                                1             10.0
# Nancy                                        1             10.0
# MC Haps                                      1             10.0
# Harold                                       1             10.0
# Cronenberg Morty                             1             10.0
# Cronenberg Rick                              1             10.0
# Brad                                         1             10.0
# Giant Judge                                  1             10.0
# Stair Goblin                                 1             10.0
# Tom Randolph                                 1             10.0
# Slippery Stair                               1             10.0
# Samantha                                     1             10.0
# Mr. Meeseeks                                 1             10.0
# Mr. Booby Buyer                              1             10.0
# King Jellybean                               1             10.0
# Evil Summer Clone                            1             10.0
# Evil Jerry Clone                             1             10.0
# Evil Beth Clone                              1             10.0
# Dale                                         1             10.0
# Big Boobed Waitress                          1             10.0
# Stu                                          1             10.0
# Prince Nebulon                               1             10.0
# Mr. Marklovitz                               1             10.0
# Kevin                                        1             10.0
# Rat Boss                                     1             10.0
#
# [152 rows x 2 columns]

# %%
# Guardamos el DataFrame en un archivo
save_df(df, l_epi=set_episodios)

# %%
# Mejoras futuras

# %%
df_final = create_df_p(df, personajes_episodios, total_personajes)
df_final
# Out:
#                                    Appereances  Appereances (%)  0  1  2  3  \
# Characters
# Rick Sanchez                                11            110.0  1  1  1  1
# Beth Smith                                  11            110.0  1  1  1  1
# Morty Smith                                 11            110.0  1  1  1  1
# Summer Smith                                11            110.0  1  1  1  1
# Jerry Smith                                 10            100.0  1  1  1  1
# Mr. Goldenfold                               5             50.0  1  1  0  1
# Principal Vagina                             4             40.0  1  0  0  0
# Davin                                        4             40.0  1  0  0  0
# Snuffles (Snowball)                          3             30.0  0  1  0  0
# Jessica                                      3             30.0  1  0  0  1
# Jessica's Friend                             3             30.0  1  0  0  1
# Trunkphobic suspenders guy                   2             20.0  0  1  0  0
# Bill                                         2             20.0  0  1  1  0
# Tammy Guetermann                             2             20.0  0  0  0  0
# Mrs. Sanchez                                 2             20.0  1  0  0  0
# Glenn                                        2             20.0  1  0  0  0
# Cynthia                                      2             20.0  0  0  0  1
# Shmlangela Shmlobinson-Shmlower              1             10.0  0  0  0  0
# Regular Legs                                 1             10.0  0  0  0  0
# Real Fake Doors Salesman                     1             10.0  0  0  0  0
# Piece of Toast                               1             10.0  0  0  0  0
# Shmlamantha Shmlicelli                       1             10.0  0  0  0  0
# Unmuscular Michael                           1             10.0  0  0  0  0
# Shmlona Shmlobinson                          1             10.0  0  0  0  0
# Shmlonathan Shmlower                         1             10.0  0  0  0  0
# Shmlony Shmlicelli                           1             10.0  0  0  0  0
# Guy from The Bachelor                        1             10.0  0  0  0  0
# Tophat Jones                                 1             10.0  0  0  0  0
# Trunk Man                                    1             10.0  0  0  0  0
# Two Guys with Handlebar Mustaches            1             10.0  0  0  0  0
# ...                                        ...              ... .. .. .. ..
# Veronica Ann Bennet                          1             10.0  0  0  0  0
# Pawnshop Clerk                               1             10.0  0  0  0  0
# Morty Jr.                                    1             10.0  0  0  0  0
# Ma-Sha                                       1             10.0  0  0  0  0
# Gwendolyn                                    1             10.0  0  0  0  0
# Brad Anderson                                1             10.0  0  0  0  0
# Nancy                                        1             10.0  0  0  0  0
# MC Haps                                      1             10.0  0  0  0  0
# Harold                                       1             10.0  0  0  0  0
# Cronenberg Morty                             1             10.0  0  0  0  0
# Cronenberg Rick                              1             10.0  0  0  0  0
# Brad                                         1             10.0  0  0  0  0
# Giant Judge                                  1             10.0  0  0  0  0
# Stair Goblin                                 1             10.0  0  0  0  0
# Tom Randolph                                 1             10.0  0  0  1  0
# Slippery Stair                               1             10.0  0  0  0  0
# Samantha                                     1             10.0  0  0  0  0
# Mr. Meeseeks                                 1             10.0  0  0  0  0
# Mr. Booby Buyer                              1             10.0  0  0  0  0
# King Jellybean                               1             10.0  0  0  0  0
# Evil Summer Clone                            1             10.0  0  0  0  0
# Evil Jerry Clone                             1             10.0  0  0  0  0
# Evil Beth Clone                              1             10.0  0  0  0  0
# Dale                                         1             10.0  0  0  0  0
# Big Boobed Waitress                          1             10.0  0  0  0  0
# Stu                                          1             10.0  0  0  0  1
# Prince Nebulon                               1             10.0  0  0  0  1
# Mr. Marklovitz                               1             10.0  0  0  0  1
# Kevin                                        1             10.0  0  0  0  1
# Rat Boss                                     1             10.0  0  0  0  0
#
#                                    4  5  6  7  8  9
# Characters
# Rick Sanchez                       1  1  1  1  1  1
# Beth Smith                         1  1  1  1  1  1
# Morty Smith                        1  1  1  1  1  1
# Summer Smith                       1  1  1  1  1  1
# Jerry Smith                        1  1  1  1  1  0
# Mr. Goldenfold                     0  1  0  0  0  1
# Principal Vagina                   1  1  0  0  0  1
# Davin                              0  1  0  0  0  0
# Snuffles (Snowball)                0  0  1  0  0  1
# Jessica                            0  1  0  0  0  0
# Jessica's Friend                   0  1  0  0  0  0
# Trunkphobic suspenders guy         0  0  0  1  0  0
# Bill                               0  0  0  0  0  0
# Tammy Guetermann                   1  1  0  0  0  0
# Mrs. Sanchez                       0  1  0  0  0  0
# Glenn                              0  0  0  1  0  0
# Cynthia                            0  0  0  1  0  0
# Shmlangela Shmlobinson-Shmlower    0  0  0  1  0  0
# Regular Legs                       0  0  0  1  0  0
# Real Fake Doors Salesman           0  0  0  1  0  0
# Piece of Toast                     0  0  0  1  0  0
# Shmlamantha Shmlicelli             0  0  0  1  0  0
# Unmuscular Michael                 0  0  0  1  0  0
# Shmlona Shmlobinson                0  0  0  1  0  0
# Shmlonathan Shmlower               0  0  0  1  0  0
# Shmlony Shmlicelli                 0  0  0  1  0  0
# Guy from The Bachelor              0  0  0  1  0  0
# Tophat Jones                       0  0  0  1  0  0
# Trunk Man                          0  0  0  1  0  0
# Two Guys with Handlebar Mustaches  0  0  0  1  0  0
# ...                               .. .. .. .. .. ..
# Veronica Ann Bennet                0  0  1  0  0  0
# Pawnshop Clerk                     0  0  1  0  0  0
# Morty Jr.                          0  0  1  0  0  0
# Ma-Sha                             0  0  1  0  0  0
# Gwendolyn                          0  0  1  0  0  0
# Brad Anderson                      0  0  1  0  0  0
# Nancy                              0  1  0  0  0  0
# MC Haps                            0  1  0  0  0  0
# Harold                             0  1  0  0  0  0
# Cronenberg Morty                   0  1  0  0  0  0
# Cronenberg Rick                    0  1  0  0  0  0
# Brad                               0  1  0  0  0  0
# Giant Judge                        1  0  0  0  0  0
# Stair Goblin                       1  0  0  0  0  0
# Tom Randolph                       0  0  0  0  0  0
# Slippery Stair                     1  0  0  0  0  0
# Samantha                           1  0  0  0  0  0
# Mr. Meeseeks                       1  0  0  0  0  0
# Mr. Booby Buyer                    1  0  0  0  0  0
# King Jellybean                     1  0  0  0  0  0
# Evil Summer Clone                  1  0  0  0  0  0
# Evil Jerry Clone                   1  0  0  0  0  0
# Evil Beth Clone                    1  0  0  0  0  0
# Dale                               1  0  0  0  0  0
# Big Boobed Waitress                1  0  0  0  0  0
# Stu                                0  0  0  0  0  0
# Prince Nebulon                     0  0  0  0  0  0
# Mr. Marklovitz                     0  0  0  0  0  0
# Kevin                              0  0  0  0  0  0
# Rat Boss                           0  0  0  0  0  1
#
# [152 rows x 12 columns]

# %%
# Guardamos el DataFrame en un archivo
save_df(df_final, l_epi=set_episodios)
