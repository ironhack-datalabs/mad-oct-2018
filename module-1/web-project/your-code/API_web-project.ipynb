# %%
#Importamos las librerías principales para esta práctica
import json
import requests
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %% [markdown]
# ### Importamos datos

# %%
#A través de response, importamos todos los datos. 
response = requests.get('http://makeup-api.herokuapp.com/api/v1/products.json')

# %%
#Normalizamos nuestros datos
results = response.json()
df = json_normalize(results)
df.head()
# Out:
#                                   api_featured_image      brand  category  \
# 0  //s3.amazonaws.com/donovanbailey/products/api_...  colourpop    pencil
# 1  //s3.amazonaws.com/donovanbailey/products/api_...  colourpop  lipstick
# 2  //s3.amazonaws.com/donovanbailey/products/api_...  colourpop  lipstick
# 3  //s3.amazonaws.com/donovanbailey/products/api_...  colourpop    liquid
# 4  //s3.amazonaws.com/donovanbailey/products/api_...      boosh  lipstick
#
#                  created_at currency  \
# 0  2018-07-08T23:45:08.056Z      CAD
# 1  2018-07-08T22:01:20.178Z      CAD
# 2  2018-07-08T21:47:49.858Z      CAD
# 3  2018-07-08T18:22:25.273Z      CAD
# 4  2018-07-08T17:32:28.088Z      CAD
#
#                                          description    id  \
# 0  Lippie Pencil A long-wearing and high-intensit...  1048
# 1  Blotted Lip Sheer matte lipstick that creates ...  1047
# 2  Lippie Stix Formula contains Vitamin E, Mango,...  1046
# 3  Developed for the Selfie Age, our buildable fu...  1045
# 4  All of our products are free from lead and hea...  1044
#
#                                           image_link                  name  \
# 0  https://cdn.shopify.com/s/files/1/1338/0845/co...         Lippie Pencil
# 1  https://cdn.shopify.com/s/files/1/1338/0845/pr...           Blotted Lip
# 2  https://cdn.shopify.com/s/files/1/1338/0845/co...           Lippie Stix
# 3  https://cdn.shopify.com/s/files/1/1338/0845/pr...  No Filter Foundation
# 4  https://cdn.shopify.com/s/files/1/1016/3243/pr...              Lipstick
#
#   price price_sign                                    product_api_url  \
# 0   5.0          $  http://makeup-api.herokuapp.com/api/v1/product...
# 1   5.5          $  http://makeup-api.herokuapp.com/api/v1/product...
# 2   5.5          $  http://makeup-api.herokuapp.com/api/v1/product...
# 3  12.0          $  http://makeup-api.herokuapp.com/api/v1/product...
# 4  26.0          $  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                       product_colors  \
# 0  [{'hex_value': '#AB7164', 'colour_name': 'BFF ...
# 1  [{'hex_value': '#7C3F35', 'colour_name': 'Cand...
# 2  [{'hex_value': '#975450', 'colour_name': 'Kapi...
# 3  [{'hex_value': '#6B5148', 'colour_name': 'Deep...
# 4  [{'hex_value': '#9D3F47', 'colour_name': 'Ruby...
#
#                                         product_link product_type  rating  \
# 0    https://colourpop.com/collections/lippie-pencil    lip_liner     NaN
# 1  https://colourpop.com/collections/lippie-stix?...     lipstick     NaN
# 2      https://colourpop.com/collections/lippie-stix     lipstick     NaN
# 3  https://colourpop.com/products/no-filter-matte...   foundation     NaN
# 4               https://www.boosh.ca/collections/all     lipstick     NaN
#
#                    tag_list                updated_at  \
# 0     [Vegan, cruelty free]  2018-07-09T00:53:23.301Z
# 1     [Vegan, cruelty free]  2018-07-09T00:53:23.287Z
# 2     [Vegan, cruelty free]  2018-07-09T00:53:23.274Z
# 3     [Vegan, cruelty free]  2018-07-09T00:53:23.313Z
# 4  [Organic, Chemical Free]  2018-09-02T22:52:06.669Z
#
#                                         website_link
# 0                              https://colourpop.com
# 1                              https://colourpop.com
# 2                              https://colourpop.com
# 3  https://colourpop.com/products/no-filter-matte...
# 4                              https://www.boosh.ca/

# %% [markdown]
# ### Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 931 entries, 0 to 930
# Data columns (total 13 columns):
# id                931 non-null int64
# name              931 non-null object
# brand             919 non-null object
# product_type      931 non-null object
# price             917 non-null object
# price_sign        368 non-null object
# rating            340 non-null float64
# description       930 non-null object
# tag_list          931 non-null object
# website_link      931 non-null object
# product_link      931 non-null object
# updated_at        931 non-null object
# product_colors    931 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 94.6+ KB

# %% [markdown]
# #### Problemas al normalizar columna "product_colors"
# Normalizar columna product_colors. <br>
# De momento, no podemos normalizar la columna de product_colors, al ser una lista de listas con diccionarios.
# A lo máximo que he podido llegar es a una función que te devuelva todos los valores en el diccionario del primer término.
#
# ```Python
# def getFirstColor(l):
#     colors = json_normalize(l)
#     if not colors.empty and len(colors) > 0:
#         return (colors['colour_name'])
#     else:
#         return None
#
# display([getFirstColor(e) for e in df['product_colors'][0]])
# ```

# %%
#Eliminamos columnas innecesarias 
drop_cols = ['api_featured_image', 'product_api_url', 'image_link']
df = df.drop(drop_cols, axis = 1)
df.head()
# Out:
#        brand  category                created_at currency  \
# 0  colourpop    pencil  2018-07-08T23:45:08.056Z      CAD
# 1  colourpop  lipstick  2018-07-08T22:01:20.178Z      CAD
# 2  colourpop  lipstick  2018-07-08T21:47:49.858Z      CAD
# 3  colourpop    liquid  2018-07-08T18:22:25.273Z      CAD
# 4      boosh  lipstick  2018-07-08T17:32:28.088Z      CAD
#
#                                          description    id  \
# 0  Lippie Pencil A long-wearing and high-intensit...  1048
# 1  Blotted Lip Sheer matte lipstick that creates ...  1047
# 2  Lippie Stix Formula contains Vitamin E, Mango,...  1046
# 3  Developed for the Selfie Age, our buildable fu...  1045
# 4  All of our products are free from lead and hea...  1044
#
#                    name price price_sign  \
# 0         Lippie Pencil   5.0          $
# 1           Blotted Lip   5.5          $
# 2           Lippie Stix   5.5          $
# 3  No Filter Foundation  12.0          $
# 4              Lipstick  26.0          $
#
#                                       product_colors  \
# 0  [{'hex_value': '#AB7164', 'colour_name': 'BFF ...
# 1  [{'hex_value': '#7C3F35', 'colour_name': 'Cand...
# 2  [{'hex_value': '#975450', 'colour_name': 'Kapi...
# 3  [{'hex_value': '#6B5148', 'colour_name': 'Deep...
# 4  [{'hex_value': '#9D3F47', 'colour_name': 'Ruby...
#
#                                         product_link product_type  rating  \
# 0    https://colourpop.com/collections/lippie-pencil    lip_liner     NaN
# 1  https://colourpop.com/collections/lippie-stix?...     lipstick     NaN
# 2      https://colourpop.com/collections/lippie-stix     lipstick     NaN
# 3  https://colourpop.com/products/no-filter-matte...   foundation     NaN
# 4               https://www.boosh.ca/collections/all     lipstick     NaN
#
#                    tag_list                updated_at  \
# 0     [Vegan, cruelty free]  2018-07-09T00:53:23.301Z
# 1     [Vegan, cruelty free]  2018-07-09T00:53:23.287Z
# 2     [Vegan, cruelty free]  2018-07-09T00:53:23.274Z
# 3     [Vegan, cruelty free]  2018-07-09T00:53:23.313Z
# 4  [Organic, Chemical Free]  2018-09-02T22:52:06.669Z
#
#                                         website_link
# 0                              https://colourpop.com
# 1                              https://colourpop.com
# 2                              https://colourpop.com
# 3  https://colourpop.com/products/no-filter-matte...
# 4                              https://www.boosh.ca/

# %%
#Ordenamos nuestras columnas. 
col_order = ['id', 'name', 'brand','product_type', 'price', 'price_sign', 'rating', 'description', 'tag_list', 'website_link', 'product_link', 'updated_at', 'product_colors']
df = df[col_order]
df.head()
# Out:
#      id                  name      brand product_type price price_sign  \
# 0  1048         Lippie Pencil  colourpop    lip_liner   5.0          $
# 1  1047           Blotted Lip  colourpop     lipstick   5.5          $
# 2  1046           Lippie Stix  colourpop     lipstick   5.5          $
# 3  1045  No Filter Foundation  colourpop   foundation  12.0          $
# 4  1044              Lipstick      boosh     lipstick  26.0          $
#
#    rating                                        description  \
# 0     NaN  Lippie Pencil A long-wearing and high-intensit...
# 1     NaN  Blotted Lip Sheer matte lipstick that creates ...
# 2     NaN  Lippie Stix Formula contains Vitamin E, Mango,...
# 3     NaN  Developed for the Selfie Age, our buildable fu...
# 4     NaN  All of our products are free from lead and hea...
#
#                    tag_list  \
# 0     [Vegan, cruelty free]
# 1     [Vegan, cruelty free]
# 2     [Vegan, cruelty free]
# 3     [Vegan, cruelty free]
# 4  [Organic, Chemical Free]
#
#                                         website_link  \
# 0                              https://colourpop.com
# 1                              https://colourpop.com
# 2                              https://colourpop.com
# 3  https://colourpop.com/products/no-filter-matte...
# 4                              https://www.boosh.ca/
#
#                                         product_link  \
# 0    https://colourpop.com/collections/lippie-pencil
# 1  https://colourpop.com/collections/lippie-stix?...
# 2      https://colourpop.com/collections/lippie-stix
# 3  https://colourpop.com/products/no-filter-matte...
# 4               https://www.boosh.ca/collections/all
#
#                  updated_at                                     product_colors
# 0  2018-07-09T00:53:23.301Z  [{'hex_value': '#AB7164', 'colour_name': 'BFF ...
# 1  2018-07-09T00:53:23.287Z  [{'hex_value': '#7C3F35', 'colour_name': 'Cand...
# 2  2018-07-09T00:53:23.274Z  [{'hex_value': '#975450', 'colour_name': 'Kapi...
# 3  2018-07-09T00:53:23.313Z  [{'hex_value': '#6B5148', 'colour_name': 'Deep...
# 4  2018-09-02T22:52:06.669Z  [{'hex_value': '#9D3F47', 'colour_name': 'Ruby...

# %% [markdown]
# ### Definición de función

# %%
#Extraemos los valores únicos de la columna "brand" y creamos una lista 
brand_list = df.brand.unique().tolist()

# %%
#Extraemos los valores únicos de la columna "product_type" y creamos una lista 
product_type_list= df.product_type.unique().tolist()

# %%
#Definimos la función 
def consult (data):
    print("Brands: ", (brand_list))
    print("Product type: ", (product_type_list))
    brand_q = input("Please enter a brand: ")
    product_q = str(input("Please enter a product type: "))
    if brand_q.lower() in brand_list:
        if product_q.lower() in product_type_list:
            return(data.loc[(df['brand'] == brand_q) & (data['product_type'] == product_q)])
        else:
            return ("The brand or type of product are not available on the website")

# %%
#Llamamos a la función con los datos del dataframe de la API
consult(df)
# Out:
# Brands:  ['colourpop', 'boosh', 'deciem', 'zorah biocosmetiques', 'w3llpeople', "sally b's skin yummies", 'rejuva minerals', 'penny lane organics', 'nudus', 'marienatie', "maia's mineral galaxy", 'lotus cosmetics usa', 'green people', 'coastal classic creation', "c'est moi", 'alva', 'glossier', 'nyx', 'fenty', 'clinique', 'dior', 'iman', 'benefit', 'smashbox', 'marcelle', 'stila', 'mineral fusion', None, 'annabelle', 'dr. hauschka', 'physicians formula', 'cargo cosmetics', 'covergirl', 'e.l.f.', 'maybelline', 'almay', 'milani', 'pure anada', "l'oreal", 'sante', 'revlon', 'anna sui', 'wet n wild', 'pacifica', 'mistura', 'zorah', 'suncoat', 'moov', 'misa', 'salon perfect', 'orly', 'china glaze', 'essie', 'butter london', 'sinful colours', 'piggy paint', 'dalish', "burt's bees"]
# Product type:  ['lip_liner', 'lipstick', 'foundation', 'eyeliner', 'eyeshadow', 'blush', 'bronzer', 'mascara', 'eyebrow', 'nail_polish']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/.local/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/.local/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/.local/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-374e2a572937> in <module>
#       1 #Llamamos a la función con los datos del dataframe de la API
# ----> 2 consult(df)
#
# <ipython-input-21-231594b16565> in consult(data)
#       3     print("Brands: ", (brand_list))
#       4     print("Product type: ", (product_type_list))
# ----> 5     brand_q = input("Please enter a brand: ")
#       6     product_q = str(input("Please enter a product type: "))
#       7     if brand_q.lower() in brand_list:
#
# ~/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# ~/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:
