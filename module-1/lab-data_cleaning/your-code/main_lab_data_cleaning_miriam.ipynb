# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
engine = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz/stats')

# %% [markdown]
# #### 4. Import the users table

# %%
data = pd.read_sql_query('SELECT * FROM stats.users', engine)
print(data)
# Out:
#           Id  Reputation        CreationDate          DisplayName  \
# 0         -1           1 2010-07-19 06:55:26            Community
# 1          2         101 2010-07-19 14:01:36         Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50         Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27               Emmett
# 4          5        6792 2010-07-19 19:03:57                Shane
# 5          6         457 2010-07-19 19:04:07               Harlan
# 6          7         429 2010-07-19 19:04:37                Vince
# 7          8        6764 2010-07-19 19:04:52          csgillespie
# 8         10         121 2010-07-19 19:05:40               Pierre
# 9         11         136 2010-07-19 19:06:02             wahalulu
# 10        12         101 2010-07-19 19:06:34                  Jin
# 11        13         817 2010-07-19 19:06:49              Sharpie
# 12        15          11 2010-07-19 19:07:32        hannes.koller
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
data = data.rename(columns={'Id':'userId'})

# %%
print(data).sort_values('userId')
# Out:
#        userId  Reputation        CreationDate          DisplayName  \
# 0          -1           1 2010-07-19 06:55:26            Community
# 1           2         101 2010-07-19 14:01:36         Geoff Dalgas
# 2           3         101 2010-07-19 15:34:50         Jarrod Dixon
# 3           4         101 2010-07-19 19:03:27               Emmett
# 4           5        6792 2010-07-19 19:03:57                Shane
# 5           6         457 2010-07-19 19:04:07               Harlan
# 6           7         429 2010-07-19 19:04:37                Vince
# 7           8        6764 2010-07-19 19:04:52          csgillespie
# 8          10         121 2010-07-19 19:05:40               Pierre
# 9          11         136 2010-07-19 19:06:02             wahalulu
# 10         12         101 2010-07-19 19:06:34                  Jin
# 11         13         817 2010-07-19 19:06:49              Sharpie
# 12         15          11 2010-07-19 19:07:32        hannes.koller
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
posts = pd.read_sql_query('SELECT * FROM stats.posts', engine)
# Out:
#            Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# 5           6           1               NaN 2010-07-19 19:14:44    152
# 6           7           1              18.0 2010-07-19 19:15:59     76
# 7           8           1               NaN 2010-07-19 19:16:21      0
# 8           9           2               NaN 2010-07-19 19:16:27     13
# 9          10           1            1887.0 2010-07-19 19:17:47     23
# 10         11           1            1201.0 2010-07-19 19:18:30      2
# 11         12           2               NaN 2010-07-19 19:18:41     20
# ...

# %%
print(posts)
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# 5           6           1               NaN 2010-07-19 19:14:44    152
# 6           7           1              18.0 2010-07-19 19:15:59     76
# 7           8           1               NaN 2010-07-19 19:16:21      0
# 8           9           2               NaN 2010-07-19 19:16:27     13
# 9          10           1            1887.0 2010-07-19 19:17:47     23
# 10         11           1            1201.0 2010-07-19 19:18:30      2
# 11         12           2               NaN 2010-07-19 19:18:41     20
# ...

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts = posts.rename(columns={'Id': 'postId',
                             'OwnerUserId': 'userId'})
print(posts)
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# 5           6           1               NaN 2010-07-19 19:14:44    152
# 6           7           1              18.0 2010-07-19 19:15:59     76
# 7           8           1               NaN 2010-07-19 19:16:21      0
# 8           9           2               NaN 2010-07-19 19:16:27     13
# 9          10           1            1887.0 2010-07-19 19:17:47     23
# 10         11           1            1201.0 2010-07-19 19:18:30      2
# 11         12           2               NaN 2010-07-19 19:18:41     20
# ...

# %%
print(data.dtypes)
# Out:
# userId                      int64
# Reputation                  int64
# CreationDate       datetime64[ns]
# DisplayName                object
# LastAccessDate     datetime64[ns]
# WebsiteUrl                 object
# Location                   object
# AboutMe                    object
# Views                       int64
# UpVotes                     int64
# DownVotes                   int64
# AccountId                   int64
# Age                       float64
# ProfileImageUrl            object
# dtype: object

# %%
print(posts.dtypes)
# Out:
# postId                            int64
# PostTypeId                        int64
# AcceptedAnswerId                float64
# CreaionDate              datetime64[ns]
# Score                             int64
# ViewCount                       float64
# Body                             object
# userId                          float64
# LasActivityDate          datetime64[ns]
# Title                            object
# Tags                             object
# AnswerCount                     float64
# CommentCount                      int64
# FavoriteCount                   float64
# LastEditorUserId                float64
# LastEditDate             datetime64[ns]
# CommunityOwnedDate       datetime64[ns]
# ParentId                        float64
# ClosedDate               datetime64[ns]
# OwnerDisplayName                 object
# LastEditorDisplayName            object
# dtype: object

# %% [markdown]
# #### Comprobamos que 'data.userId' es de tipo int64
# #### En cambio 'posts.userId' es de tipo float64
# #### Corregimos el tipo de datos en 'posts.userId'

# %%
###posts['userId'] = posts['userId'].astype('int64')
###posts['userId'].dtype
### Erro, no puede convertir NaN en int64

# %%
posts['userId'] = posts['userId'].fillna(0)
posts['userId'] = posts['userId'].astype('int64')
print(posts)
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# 5           6           1               NaN 2010-07-19 19:14:44    152
# 6           7           1              18.0 2010-07-19 19:15:59     76
# 7           8           1               NaN 2010-07-19 19:16:21      0
# 8           9           2               NaN 2010-07-19 19:16:27     13
# 9          10           1            1887.0 2010-07-19 19:17:47     23
# 10         11           1            1201.0 2010-07-19 19:18:30      2
# 11         12           2               NaN 2010-07-19 19:18:41     20
# ...

# %%
print(posts.sort_values('userId'))
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 53015   65302           5               NaN 2013-07-23 19:21:07      0
# 5167     5586           1               NaN 2010-12-17 06:31:41      1
# 1135     1218           2               NaN 2010-08-04 06:51:12      0
# 5182     5604           1               NaN 2010-12-17 19:04:04      3
# 5190     5612           2               NaN 2010-12-17 23:02:12      0
# 5196     5619           1               NaN 2010-12-18 15:33:30      4
# 5203     5626           2               NaN 2010-12-19 00:59:28      2
# 5204     5627           2               NaN 2010-12-19 02:56:46      1
# 29748   33252           5               NaN 2012-07-28 12:46:50      0
# 5221     5647           1               NaN 2010-12-20 12:30:03      2
# 49893   61575           1               NaN 2013-06-12 18:02:04      1
# 5158     5576           2               NaN 2010-12-16 20:16:41      0
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
users_new = data[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
print(users_new)
posts_new = posts[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]
print(posts_new)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# 5           6         457    114       47          0
# 6           7         429     56       20          0
# 7           8        6764   1089      604         25
# 8          10         121     20        2          0
# 9          11         136     10       10          0
# 10         12         101     10        5          0
# 11         13         817    178       44          1
# 12         15          11      8        0          0
# 13         16         101      4        7          0
# 14         17         345     14       13          1
# 15         18         128      8       16          0
# 16         19         101     13        2          0
# ...

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
data2 = pd.merge(users_new, posts_new, on='userId')
print(data2)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920      17      9
# 1          -1           1      0     5007       1920      28      6
# 2          -1           1      0     5007       1920      56     56
# 3          -1           1      0     5007       1920     101     40
# 4          -1           1      0     5007       1920     152      9
# 5          -1           1      0     5007       1920     193      6
# 6          -1           1      0     5007       1920     207     48
# 7          -1           1      0     5007       1920     303      2
# 8          -1           1      0     5007       1920     310      1
# 9          -1           1      0     5007       1920     312      4
# 10         -1           1      0     5007       1920     318      4
# 11         -1           1      0     5007       1920     368      2
# 12         -1           1      0     5007       1920     396     31
# ...

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
null_cols=data2.isnull().sum()
null_cols[null_cols>0]
#### 49055 *missing values* en nuestro dataframe data2
# Out:
# ViewCount    49055
# dtype: int64

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
## 49055/91976 = 0.5333456553883622
## Tenemos más del 50% de valores como NaN. Conclusión: eliminar la columna.

# %%
drop_cols = list(null_cols [null_cols>45000].index)
data2 = data2.drop(drop_cols, axis = 1)

# %%
print(data2)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920      17      9
# 1          -1           1      0     5007       1920      28      6
# 2          -1           1      0     5007       1920      56     56
# 3          -1           1      0     5007       1920     101     40
# 4          -1           1      0     5007       1920     152      9
# 5          -1           1      0     5007       1920     193      6
# 6          -1           1      0     5007       1920     207     48
# 7          -1           1      0     5007       1920     303      2
# 8          -1           1      0     5007       1920     310      1
# 9          -1           1      0     5007       1920     312      4
# 10         -1           1      0     5007       1920     318      4
# 11         -1           1      0     5007       1920     368      2
# 12         -1           1      0     5007       1920     396     31
# ...

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
### he ajustado el data type de posts.userId

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.
