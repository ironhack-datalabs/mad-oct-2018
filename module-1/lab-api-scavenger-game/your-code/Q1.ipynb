# %%
import json
import requests
import pandas as pd

response = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018')
results = response.json()
results
# Out:
# {'id': 153720804,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=',
#  'name': 'madrid-oct-2018',
#  'full_name': 'ironhack-datalabs/madrid-oct-2018',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
data = pd.DataFrame(results)
display(data)
# Out:
#                             id                           node_id  \
# archive_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# archived             153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# assignees_url        153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# avatar_url           153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# blobs_url            153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# branches_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# clone_url            153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# collaborators_url    153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# comments_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# commits_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# compare_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# contents_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# contributors_url     153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# ...

# %% [markdown]
# data

# %%
data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
data[["fork", "forks_url", "forks_count", "forks"]]
# Out:
#                      fork                                          forks_url  \
# archive_url          True  https://api.github.com/repos/ironhack-datalabs...
# archived             True  https://api.github.com/repos/ironhack-datalabs...
# assignees_url        True  https://api.github.com/repos/ironhack-datalabs...
# avatar_url           True  https://api.github.com/repos/ironhack-datalabs...
# blobs_url            True  https://api.github.com/repos/ironhack-datalabs...
# branches_url         True  https://api.github.com/repos/ironhack-datalabs...
# clone_url            True  https://api.github.com/repos/ironhack-datalabs...
# collaborators_url    True  https://api.github.com/repos/ironhack-datalabs...
# comments_url         True  https://api.github.com/repos/ironhack-datalabs...
# commits_url          True  https://api.github.com/repos/ironhack-datalabs...
# compare_url          True  https://api.github.com/repos/ironhack-datalabs...
# ...

# %%
fork_language= data.language.unique()
