# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

response1 = requests.get("https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits")
results1 = response1.json()
results_df1 = pd.DataFrame(results1)
results_df1.head()
# Out:
#                                               author  \
# 0  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 1  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 2  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 3  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 4  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                               commit  \
# 0  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 1  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 2  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 3  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# ...

# %%
results_df1.columns
# Out:
# Index(['author', 'comments_url', 'commit', 'committer', 'html_url', 'node_id',
#        'parents', 'sha', 'url'],
#       dtype='object')

# %%
results_df1["committer.login"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\pablo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'committer.login'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f381c7404448> in <module>
# ...

# %%
results_df1[(results_df1["committer.date"]>"2018-10-20") & (results_df1["committer.date"]<"2018-10-25")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\pablo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'committer.date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9c9971ef3dd3> in <module>
# ...
