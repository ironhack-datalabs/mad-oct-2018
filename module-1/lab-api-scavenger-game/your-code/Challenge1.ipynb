# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks')
results = response.json()

# %%
import json
with open('/home/cristina/Ironhack/madrid-oct-2018/module-1/lab-api-scavenger-game/output2.json') as f:
    data = json.load(f)
display(data)
# Out:
# [{'id': 154625001,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNTQ2MjUwMDE=',
#   'name': 'madrid-oct-2018',
#   'full_name': 'ArieHassan/madrid-oct-2018',
#   'private': False,
#   'owner': {'login': 'ArieHassan',
#    'id': 43290133,
#    'node_id': 'MDQ6VXNlcjQzMjkwMTMz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/43290133?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ArieHassan',
#    'html_url': 'https://github.com/ArieHassan',
#    'followers_url': 'https://api.github.com/users/ArieHassan/followers',
#    'following_url': 'https://api.github.com/users/ArieHassan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ArieHassan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ArieHassan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ArieHassan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ArieHassan/orgs',
# ...

# %%
language = pd.DataFrame(data)['language']
display(language.value_counts())
# Out:
# HTML                7
# Jupyter Notebook    3
# Python              2
# Name: language, dtype: int64

# %% [markdown]
# Loop the JSON response for the language attribute of each fork. Use an array to store the language attributes of each fork. The values in the array should be unique.

# %%
language.unique()
# Out:
# array(['HTML', 'Jupyter Notebook', 'Python'], dtype=object)

# %% [markdown]
# #Challenge 2: Count Commits
#
# #Count how many commits were made between October 20, 2018 and October 25, 2018.
# #Obtain all the commits made between October 20, 2018 and October 25, 2018 via API, which is a JSON array that contains multiple commit objects.
# #Count how many commit objects are there in the array.

# %%
data2=  pd.DataFrame(data)
display((data2).head())
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/ArieHassan/madrid...     False
# 1  https://api.github.com/repos/cmvalma/madrid-oc...     False
# 2  https://api.github.com/repos/criraca/madrid-oc...     False
# 3  https://api.github.com/repos/boyander/madrid-o...     False
# 4  https://api.github.com/repos/AlbertoCastellano...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/ArieHassan/madrid...
# 1  https://api.github.com/repos/cmvalma/madrid-oc...
# 2  https://api.github.com/repos/criraca/madrid-oc...
# 3  https://api.github.com/repos/boyander/madrid-o...
# 4  https://api.github.com/repos/AlbertoCastellano...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/ArieHassan/madrid...
# 1  https://api.github.com/repos/cmvalma/madrid-oc...
# 2  https://api.github.com/repos/criraca/madrid-oc...
# ...

# %%
response_comm = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits')
results_comm = response_comm.json()
display(results_comm)
# Out:
# [{'sha': '48de91c634cdf5d535c274f98092adf2bb3fa347',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjQ4ZGU5MWM2MzRjZGY1ZDUzNWMyNzRmOTgwOTJhZGYyYmIzZmEzNDc=',
#   'commit': {'author': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2018-10-30T05:06:04Z'},
#    'committer': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2018-10-30T05:06:04Z'},
#    'message': 'minor improvement of scavenger game',
#    'tree': {'sha': '53545633ff24f17ee7240168df1925a329b9031c',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/git/trees/53545633ff24f17ee7240168df1925a329b9031c'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/git/commits/48de91c634cdf5d535c274f98092adf2bb3fa347',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
results_comm2= json_normalize(results_comm)
display((results_comm2).head())
# Out:
#                                    author.avatar_url  \
# 0  https://avatars3.githubusercontent.com/u/16597...
# 1  https://avatars3.githubusercontent.com/u/16597...
# 2  https://avatars3.githubusercontent.com/u/16597...
# 3  https://avatars3.githubusercontent.com/u/16597...
# 4  https://avatars3.githubusercontent.com/u/16597...
#
#                                    author.events_url  \
# 0  https://api.github.com/users/eye8/events{/priv...
# 1  https://api.github.com/users/eye8/events{/priv...
# 2  https://api.github.com/users/eye8/events{/priv...
# 3  https://api.github.com/users/eye8/events{/priv...
# 4  https://api.github.com/users/eye8/events{/priv...
#
#                           author.followers_url  \
# 0  https://api.github.com/users/eye8/followers
# 1  https://api.github.com/users/eye8/followers
# 2  https://api.github.com/users/eye8/followers
# 3  https://api.github.com/users/eye8/followers
# 4  https://api.github.com/users/eye8/followers
#
# ...
