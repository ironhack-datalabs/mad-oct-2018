# %% [markdown]
# # Shark Attacks

# %%
Image(url= "https://i.ytimg.com/vi/Hrp3EjCYAac/maxresdefault.jpg", width=800, height=800)
# Out:
# <img src="https://i.ytimg.com/vi/Hrp3EjCYAac/maxresdefault.jpg" width="800" height="800"/>

# %% [markdown]
# ### Imports
# Librerías

# %%
import pandas as pd
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# Abrimos el archivo CSV fuente obtenido de la siguiente URL:
#
# https://www.kaggle.com/teajay/global-shark-attacks/version/1

# %% [markdown]
# Datos en crudo

# %%
# NOTA: He ido probando diferentes encoding ya que utf-8 no es aceptada en algunos de los registros. 

data = pd.read_csv('GSAF5.csv', encoding='ISO-8859-1')

# %% [markdown]
# ### Análisis preliminar de los datos
# Cabecera

# %%
data.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %% [markdown]
# Datos estadísticos

# %%
# de aquí no podemos sacar muchos valores numéricos

stats = data.describe().transpose()
stats
# Out:
#                  count         mean          std  min      25%     50%  \
# Year            5992.0  1925.204606   286.473712  0.0  1942.00  1975.0
# original order  5992.0  2997.548899  1729.860210  2.0  1499.75  2997.5
#
#                     75%     max
# Year            2003.00  2016.0
# original order  4495.25  5993.0

# %% [markdown]
# Nombres de las columnas

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# Hay columnas con ESPACIO detrás del texto: hay que renombrarlas

# %%
# NOTA: Fallo que se pasó por alto las primeras iteraciones. 

data = data.rename(columns={'Sex ':'Sex', 
                            'Species ':'Species',
                            'Case Number': 'Case_Number', 
                            'Fatal (Y/N)': 'Fatal', 
                            'Investigator or Source': 'Source', 
                            'href formula': 'href_formula', 
                            'Case Number.1': 'Case_1', 
                            'Case Number.2': 'Case_2', 
                            'original order': 'order', 
                            'Unnamed: 22': 'Unnamed_22', 
                            'Unnamed: 23': 'Unnamed_23'
                           })

# %% [markdown]
# Columnas con valores NaN

# %%
null_cols = data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Country           43
# Area             402
# Location         496
# Activity         527
# Name             200
# Sex              567
# Age             2681
# Injury            27
# Fatal             19
# Time            3213
# Species         2934
# Source            15
# href_formula       1
# href               3
# Unnamed_22      5991
# Unnamed_23      5990
# dtype: int64

# %% [markdown]
# Eliminamos las columnas ['Unnamed_22', 'Unnamed_23'] puesto que no traen datos junto con las demás que traigan datos NaN en más de la mitad de sus registros

# %%
drop_cols = list(null_cols[null_cols > len(data)/2].index)
data1 = data.drop(drop_cols, axis=1)
data1
# Out:
#        Case_Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %% [markdown]
# Ademas de ['Unnamed_22', 'Unnamed_23'] se han eliminado las siguientes columnas:

# %%
for e in ['Unnamed_22', 'Unnamed_23']: 
    drop_cols.remove(e)
drop_cols
# Out:
# ['Time']

# %%
data1.columns
# Out:
# Index(['Case_Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Species',
#        'Source', 'pdf', 'href_formula', 'href', 'Case_1', 'Case_2', 'order'],
#       dtype='object')

# %% [markdown]
# Vamos a quedarnos con las columnas que nos interesan nada más:

# %%
data1 = data1[['Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Injury', 'Fatal', 'Species',
       'Source']]
data1
# Out:
#       Year          Type             Country                       Area  \
# 0     2016    Unprovoked                 USA                    Florida
# 1     2016    Unprovoked                 USA                    Florida
# 2     2016    Unprovoked                 USA                    Florida
# 3     2016    Unprovoked           AUSTRALIA                   Victoria
# 4     2016    Unprovoked           AUSTRALIA                   Victoria
# 5     2016          Boat           AUSTRALIA          Western Australia
# 6     2016    Unprovoked                 USA                    Florida
# 7     2016    Unprovoked                 USA                     Hawaii
# 8     2016    Unprovoked       NEW CALEDONIA             North Province
# 9     2016    Unprovoked                 USA             South Carolina
# 10    2016    Unprovoked           AUSTRALIA          Western Australia
# 11    2016    Unprovoked                 USA                    Florida
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 10 columns):
# Year        5992 non-null int64
# Type        5992 non-null object
# Country     5949 non-null object
# Area        5590 non-null object
# Location    5496 non-null object
# Activity    5465 non-null object
# Injury      5965 non-null object
# Fatal       5973 non-null object
# Species     3058 non-null object
# Source      5977 non-null object
# dtypes: int64(1), object(9)
# memory usage: 468.2+ KB

# %% [markdown]
# Se puede apreciar que hay valores muy parecidos. Vamos a unificar actividades como por ejemplo todo lo que empiece por "Surf" será 'Surfing', 'Swimming' o 'Bathing' pasarán a 'Swiming', etc. (Más adelante)

# %%
activities = data1.Activity.value_counts()
activities.head(30)
# Out:
# Surfing            904
# Swimming           819
# Fishing            414
# Spearfishing       321
# Bathing            153
# Wading             144
# Diving             123
# Standing            97
# Snorkeling          77
# Scuba diving        74
# Body boarding       54
# Body surfing        48
# Swimming            47
# Pearl diving        32
# Treading water      32
# Kayaking            28
# Boogie boarding     28
# Free diving         26
# Fell overboard      21
# Windsurfing         18
# Boogie Boarding     16
# Shark fishing       15
# Walking             15
# Fishing             12
# Surf-skiing         12
# Rowing              12
# Floating            12
# Surf skiing         12
# Canoeing            12
# Surf fishing        11
# Name: Activity, dtype: int64

# %% [markdown]
# Hay columnas con valores inválidos todavía.

# %%
null_cols = data1.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Country       43
# Area         402
# Location     496
# Activity     527
# Injury        27
# Fatal         19
# Species     2934
# Source        15
# dtype: int64

# %% [markdown]
# Eliminamos los registros con valores no válidos

# %%
data_na_clean = data1.dropna()
data_na_clean
# Out:
#       Year          Type           Country                             Area  \
# 4     2016    Unprovoked         AUSTRALIA                         Victoria
# 6     2016    Unprovoked               USA                          Florida
# 7     2016    Unprovoked               USA                           Hawaii
# 12    2016    Unprovoked               USA                       California
# 13    2016    Unprovoked               USA                          Florida
# 18    2016    Unprovoked               USA                           Hawaii
# 19    2016    Unprovoked               USA                          Florida
# 20    2016    Unprovoked             SPAIN                Alicante Province
# 22    2016          Boat         AUSTRALIA                Western Australia
# 23    2016      Provoked               USA                          Florida
# 27    2016    Unprovoked           BAHAMAS                    Abaco Islands
# ...

# %% [markdown]
# Se puede comprobar que las columnas con valores nan son 0 ahora

# %%
null_cols = data_na_clean.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Mejora de los datos

# %% [markdown]
# Una vez eliminadas las columnas cuyos datos son inválidos y los registros que contienen valores también inválidos para nosotros o que no aporten información pasamos a mejorar la calidad de los datos

# %% [markdown]
# Con el ejemplo de diferentes actividades

# %%
activities = data_na_clean.Activity.value_counts()
activities.head(20)
# Out:
# Surfing                  844
# Fishing                  662
# Swimming                 524
# Diving                   243
# Wading                    76
# Standing                  45
# Kayaking                  23
# Treading water            19
# Walking                    8
# Rowing                     7
# Paddleskiing               5
# Boating                    5
# Boat                       5
# Playing                    5
# Jumping                    4
# Canoeing                   4
# Crabbing                   3
# Jumped into the water      3
# Clamming                   3
# Sculling                   3
# Name: Activity, dtype: int64

# %% [markdown]
# Se aprecia que **data_na_clean** todavía contiene registros que pueden considerarse duplicados como: Scuba diving <-> Free diving

# %%
# NOTA: este proceso se puede realizar con pandas de una forma más fácil.

# %%
# Ejemplo de diccionario para traducir actividades
CONTAINS_ALIAS_ACTIVITY = {
    'Surfing': ['Surf', 'surf', 'board', 'Board'], 
    'Swimming': ['Swim', 'swim', 'snor', 'Snor', 'float', 'Float', 'Bath', 'bath'], 
    'Fishing': ['Fish', 'fish'], 
    'Diving': ['Divi', 'divi']
}
for key, value in CONTAINS_ALIAS_ACTIVITY.items():
    for act in value: 
        data_na_clean.loc[data_na_clean['Activity'].str.contains(act, regex=False), 'Activity'] = key

# %%
activities = data_na_clean.Activity.value_counts()
activities.head(20)
# Out:
# Surfing                  844
# Fishing                  662
# Swimming                 524
# Diving                   243
# Wading                    76
# Standing                  45
# Kayaking                  23
# Treading water            19
# Walking                    8
# Rowing                     7
# Paddleskiing               5
# Boating                    5
# Boat                       5
# Playing                    5
# Jumping                    4
# Canoeing                   4
# Crabbing                   3
# Jumped into the water      3
# Clamming                   3
# Sculling                   3
# Name: Activity, dtype: int64

# %% [markdown]
# Se puede aprceiar que se han ido agrupando los Surfing. A medida que se incremente el diccionario CONTAINS_ALIAS_ACTIVITY irá mejorando la solución

# %% [markdown]
# Con el ejemplo de diferentes tipos de ataque podemos hacer algo similar a lo realizado con actividades.

# %%
types = data_na_clean.Type.value_counts()
types
# Out:
# Unprovoked      1981
# Provoked         358
# Invalid          172
# Boat             135
# Boating           47
# Sea Disaster      19
# Name: Type, dtype: int64

# %%
CONTAINS_ALIAS_TYPE = {
    'Boating': ['Boat', 'boat']
}

# mejorable 
for key, value in CONTAINS_ALIAS_TYPE.items():
    for ty in value: 
        data_na_clean.loc[data_na_clean['Type'].str.contains(ty, regex=False), 'Type'] = key

# %%
types = data_na_clean.Type.value_counts()
types
# Out:
# Unprovoked      1981
# Provoked         358
# Boating          182
# Invalid          172
# Sea Disaster      19
# Name: Type, dtype: int64

# %% [markdown]
# Podemos apreciar que Boating ahora agrupa Boat y Boating

# %% [markdown]
# ### Conclusiones
# A continuación obtendremos algunas conclusiones de nuestros datos y realizaremos operaciones que hemos estudiado en el Bootcamp

# %%
for c in data_na_clean.columns: 
    print(c, len(data_na_clean[c].value_counts()))
# Out:
# Year 154
# Type 5
# Country 99
# Area 366
# Location 2152
# Activity 226
# Injury 1919
# Fatal 4
# Species 1405
# Source 2264

# %% [markdown]
# Se puede ver que de Species no se podrá obtener mucha información ya que no sigue ningún criterio. No hay catalogadas 1405 especies de tiburones así que habría que hacer un diccionario que tradujera los datos si queremos operar con esta columna

# %% [markdown]
# Datos estadísticos

# %%
data_na_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2712 entries, 4 to 5986
# Data columns (total 10 columns):
# Year        2712 non-null int64
# Type        2712 non-null object
# Country     2712 non-null object
# Area        2712 non-null object
# Location    2712 non-null object
# Activity    2712 non-null object
# Injury      2712 non-null object
# Fatal       2712 non-null object
# Species     2712 non-null object
# Source      2712 non-null object
# dtypes: int64(1), object(9)
# memory usage: 233.1+ KB

# %% [markdown]
# #### 1. El lugar más letal para bañarse en cada uno de los 7 paises con más mortalidad por ataque de tiburón

# %% [markdown]
# Paises donde más ataques mortales hay ordenados de más a menos peligroso.

# %%
df_paises = data_na_clean[data_na_clean['Fatal'] == 'Y']
ser_paises = df_paises['Country'].value_counts().keys()
ser_paises
# Out:
# Index(['AUSTRALIA', 'USA', 'SOUTH AFRICA', 'PAPUA NEW GUINEA', 'MEXICO',
#        'NEW ZEALAND', 'REUNION', 'CROATIA', 'NEW CALEDONIA', 'ITALY', 'PANAMA',
#        'BAHAMAS', 'FIJI', 'NEW BRITAIN', 'GREECE', 'JAMAICA', 'MOZAMBIQUE',
#        'OKINAWA', 'JAPAN', 'EGYPT', 'BRAZIL', 'HONG KONG', 'AMERICAN SAMOA',
#        'VANUATU', 'INDONESIA', 'DOMINICAN REPUBLIC', 'MALTA', 'CUBA',
#        'SOUTH KOREA', 'SPAIN', 'CHILE', 'MONTENEGRO', 'INDIA', 'SEYCHELLES',
#        'SENEGAL', 'IRAQ', ' TONGA', 'SAN DOMINGO', 'PHILIPPINES', 'NEW GUINEA',
#        'Seychelles', 'YEMEN', 'FRANCE', 'MARSHALL ISLANDS', 'CYPRUS',
#        'NICARAGUA', 'HAITI', 'TONGA', 'Sierra Leone', 'SAUDI ARABIA',
#        'SOLOMON ISLANDS', 'WESTERN SAMOA', 'CHINA', 'PACIFIC OCEAN',
#        'FRENCH POLYNESIA', 'PORTUGAL', 'EL SALVADOR', 'NORTH PACIFIC OCEAN'],
#       dtype='object')

# %% [markdown]
# Los 7 paises que han registrado más muertes por ataque de tiburón

# %%
l_7_paises_letales = list(ser_paises[0:7])
l_7_paises_letales
# Out:
# ['AUSTRALIA',
#  'USA',
#  'SOUTH AFRICA',
#  'PAPUA NEW GUINEA',
#  'MEXICO',
#  'NEW ZEALAND',
#  'REUNION']

# %% [markdown]
# ¿Dónde no ir a bañarse si vas a estos paises?

# %%
res = []
for pais in l_7_paises_letales: 
    res.append((pais, df_paises[df_paises['Country'] == pais]['Area'].value_counts().keys().max() ))
res
# Out:
# [('AUSTRALIA', 'Western Australia'),
#  ('USA', 'Virginia'),
#  ('SOUTH AFRICA', 'Western Province'),
#  ('PAPUA NEW GUINEA', 'West New Britain Province'),
#  ('REUNION', 'd\x92Étang-Salé'),
#  ('MEXICO', 'Veracruz'),
#  ('NEW ZEALAND', 'South Island')]

# %%
# Realizar un diccionario de tiburones: white, whaler, bull, tiger

# %%
# ranking de paises más tontos: ranking de paises donde los ataques son provocados

# %%
"""mortal = 
letales = data_na_clean[data_na_clean['Injury'] == 'FATAL']
num_ataques_letales = len(letales)
num_ataques_letales"""
# letales_por_especies = letales.groupby(data_na_clean['Species' ])['Species' ].nunique()
# letales_por_especies
