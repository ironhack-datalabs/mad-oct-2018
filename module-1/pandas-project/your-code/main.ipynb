# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("NBA_player_of_the_week.csv")
np.shape(data)
# Out:
# (1145, 13)

# %%
data
# Out:
#       Age Conference          Date  Draft Year Height                  Player  \
# 0      29        NaN  Apr 14, 1985        1978    6-5  Micheal Ray Richardson
# 1      23        NaN   Apr 7, 1985        1982    6-6             Derek Smith
# 2      28        NaN   Apr 1, 1985        1979    6-6             Calvin Natt
# 3      37        NaN  Mar 24, 1985        1969    7-2     Kareem Abdul-Jabbar
# 4      28        NaN  Mar 17, 1985        1978    6-9              Larry Bird
# 5      26        NaN  Mar 10, 1985        1980    6-4        Darrell Griffith
# 6      24        NaN   Mar 3, 1985        1982    6-3            Sleepy Floyd
# 7      25        NaN  Feb 24, 1985        1981    6-6            Mark Aguirre
# 8      25        NaN  Feb 17, 1985        1979    6-9           Magic Johnson
# 9      25        NaN   Feb 3, 1985        1982    6-7       Dominique Wilkins
# 10     32        NaN  Jan 27, 1985        1974   6-11            Tom McMillen
# ...

# %%
null_cols = data.isnull().sum()
null_cols
# Out:
# Age                    0
# Conference           384
# Date                   0
# Draft Year             0
# Height                 0
# Player                 0
# Position               0
# Season                 0
# Season short           0
# Seasons in league      0
# Team                   0
# Weight                 0
# Real_value             0
# dtype: int64

# %%
set(data["Conference"])
# Out:
# {'East', 'West', nan}

# %%
set(data["Team"])
# Out:
# {'Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Charlotte Bobcats',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'New Jersey Nets',
#  'New Orleans Hornets',
#  'New Orleans Pelicans',
#  'New York Knicks',
#  'Oklahoma City Thunder',
#  'Orlando Magic',
#  'Philadelphia Sixers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Seattle SuperSonics',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Washington Bullets',
#  'Washington Wizards'}

# %%
conference = pd.read_csv("conference.csv", header=None)
conference = conference.rename(columns={0:"Team", 1:"Conference"})
conference
# Out:
#                       Team Conference
# 0            Atlanta Hawks       East
# 1           Boston Celtics       East
# 2            Brooklyn Nets       East
# 3        Charlotte Bobcats       East
# 4        Charlotte Hornets       East
# 5            Chicago Bulls       East
# 6      Cleveland Cavaliers       East
# 7         Dallas Mavericks       West
# 8           Denver Nuggets       West
# 9          Detroit Pistons       East
# 10   Golden State Warriors       West
# 11         Houston Rockets       West
# 12          Indiana Pacers       East
# 13    Los Angeles Clippers       West
# 14      Los Angeles Lakers       West
# 15       Memphis Grizzlies       West
# 16              Miami Heat       East
# 17         Milwaukee Bucks       East
# 18  Minnesota Timberwolves       West
# 19         New Jersey Nets       East
# 20     New Orleans Hornets       East
# 21    New Orleans Pelicans       West
# 22         New York Knicks       East
# 23   Oklahoma City Thunder       West
# ...

# %%
merge_df = pd.merge(data, conference, on='Team')
merge_df
# Out:
#       Age Conference_x          Date  Draft Year Height  \
# 0      29          NaN  Apr 14, 1985        1978    6-5
# 1      29          NaN  Dec 30, 1984        1978    6-5
# 2      25          NaN  Nov 10, 1985        1981    6-8
# 3      24          NaN   Apr 5, 1992        1989    6-1
# 4      26          NaN  Mar 14, 1993        1990    6-2
# 5      28          NaN   Dec 6, 1992        1986    6-5
# 6      23          NaN  Jan 23, 1994        1991    6-0
# 7      31          NaN  Feb 18, 1996        1987    6-9
# 8      28          NaN  Apr 12, 1998        1993    6-3
# 9      30          NaN  Jan 25, 1998        1990   6-10
# 10     24          NaN  Nov 12, 2000        1996    6-2
# 11     28         East  Mar 24, 2002        1994    6-4
# 12     28         East   Feb 3, 2002        1994    6-4
# 13     28         East  Dec 30, 2001        1994    6-4
# 14     29         East   Apr 6, 2003        1994    6-4
# 15     22         East  Mar 30, 2003        2001    6-7
# ...

# %%
df1 = merge_df.drop(columns=["Conference_x","Draft Year","Season short"])
df1 = df1.rename(columns={"Conference_y":"Conference"})
df1
# Out:
#       Age          Date Height                  Player Position     Season  \
# 0      29  Apr 14, 1985    6-5  Micheal Ray Richardson       PG  1984-1985
# 1      29  Dec 30, 1984    6-5  Micheal Ray Richardson       PG  1984-1985
# 2      25  Nov 10, 1985    6-8           Buck Williams       PF  1985-1986
# 3      24   Apr 5, 1992    6-1         Mookie Blaylock       PG  1991-1992
# 4      26  Mar 14, 1993    6-2         Rumeal Robinson       PG  1992-1993
# 5      28   Dec 6, 1992    6-5         Drazen Petrovic       SG  1992-1993
# 6      23  Jan 23, 1994    6-0          Kenny Anderson       PG  1993-1994
# 7      31  Feb 18, 1996    6-9           Armen Gilliam       PF  1995-1996
# 8      28  Apr 12, 1998    6-3             Sam Cassell        G  1997-1998
# 9      30  Jan 25, 1998   6-10         Jayson Williams       FC  1997-1998
# 10     24  Nov 12, 2000    6-2         Stephon Marbury        G  2000-2001
# ...

# %%
set(df1["Height"])
# Out:
# {'175cm',
#  '183cm',
#  '185cm',
#  '191cm',
#  '193cm',
#  '196cm',
#  '201cm',
#  '203cm',
#  '206cm',
#  '208cm',
#  '211cm',
#  '213cm',
#  '216cm',
#  '221cm',
#  '5-10',
#  '5-11',
#  '5-9',
#  '6-0',
#  '6-1',
#  '6-10',
#  '6-11',
#  '6-2',
#  '6-3',
#  '6-4',
#  '6-5',
#  '6-6',
#  '6-7',
#  '6-8',
#  '6-9',
#  '7-0',
#  '7-1',
#  '7-2',
#  '7-3',
#  '7-4',
#  '7-6'}

# %%
df1['Team'].value_counts()
# Out:
# Los Angeles Lakers        71
# San Antonio Spurs         61
# Cleveland Cavaliers       59
# Miami Heat                57
# Houston Rockets           56
# Utah Jazz                 47
# Phoenix Suns              45
# Orlando Magic             44
# Chicago Bulls             44
# Golden State Warriors     44
# Boston Celtics            43
# Denver Nuggets            41
# Oklahoma City Thunder     41
# Philadelphia Sixers       37
# New York Knicks           36
# Portland Trail Blazers    33
# Atlanta Hawks             32
# Toronto Raptors           31
# New Jersey Nets           31
# Dallas Mavericks          30
# Detroit Pistons           29
# Los Angeles Clippers      27
# Minnesota Timberwolves    26
# Milwaukee Bucks           26
# Washington Wizards        23
# Indiana Pacers            23
# Sacramento Kings          23
# Seattle SuperSonics       20
# Charlotte Hornets         15
# New Orleans Hornets       12
# Charlotte Bobcats         11
# Memphis Grizzlies          9
# ...

# %%
df1['Player'].value_counts()
# Out:
# LeBron James               61
# Kobe Bryant                33
# Kevin Durant               26
# Michael Jordan             25
# Allen Iverson              23
# Karl Malone                23
# Tim Duncan                 23
# Shaquille O'Neal           20
# Kevin Garnett              20
# Dwyane Wade                19
# Dwight Howard              18
# James Harden               18
# Carmelo Anthony            18
# Paul Pierce                17
# Russell Westbrook          17
# Jason Kidd                 17
# Dirk Nowitzki              16
# David Robinson             15
# Chris Paul                 13
# Patrick Ewing              12
# Magic Johnson              12
# Tracy McGrady              12
# Stephen Curry              12
# Hakeem Olajuwon            12
# Vince Carter               11
# Clyde Drexler              11
# Charles Barkley            11
# LaMarcus Aldridge          10
# DeMar DeRozan              10
# Chris Bosh                  9
#                            ..
# ...

# %%
df1.dtypes
# Out:
# Age                    int64
# Date                  object
# Height                object
# Player                object
# Position              object
# Season                object
# Seasons in league      int64
# Team                  object
# Weight                object
# Real_value           float64
# Conference            object
# dtype: object

# %%
df1.values
# Out:
# array([[29, 'Apr 14, 1985', 11, ..., '189', 1.0, 'East'],
#        [29, 'Dec 30, 1984', 11, ..., '189', 1.0, 'East'],
#        [25, 'Nov 10, 1985', 14, ..., '215', 1.0, 'East'],
#        ...,
#        [24, 'Mar 5, 2018', 208, ..., '115kg', 0.5, 'West'],
#        [24, 'Nov 27, 2017', 208, ..., '115kg', 0.5, 'West'],
#        [27, 'Oct 30, 2017', 211, ..., '122kg', 0.5, 'West']], dtype=object)

# %%
bins = pd.cut(df1["Age"], 3, labels=["bad", "medium", "good"])
bins.value_counts()
# Out:
# bad       577
# medium    531
# good       37
# Name: Age, dtype: int64

# %%
bins mejores jugadores
lokation boleanos

# %%
df1['Conference'].value_counts()
# Out:
# West    579
# East    566
# Name: Conference, dtype: int64

# %%
df["Player"].astype(str).astype(int128)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-2846e960c44c> in <module>
# ----> 1 df["Player"].astype(str).astype(int128)
#
# NameError: name 'int128' is not defined

# %%
bins = pd.cut(df1["Player"], 3, labels=["bad", "medium", "good"])
bins.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-a90fb60c3824> in <module>
# ----> 1 bins = pd.cut(df1["Player"], 3, labels=["bad", "medium", "good"])
#       2 bins.head()
#
# c:\users\pablo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     206
#     207         rng = (nanops.nanmin(x), nanops.nanmax(x))
# --> 208         mn, mx = [mi + 0.0 for mi in rng]
#     209
#     210         if mn == mx:  # adjust end points before binning
#
# c:\users\pablo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\tile.py in <listcomp>(.0)
#     206
#     207         rng = (nanops.nanmin(x), nanops.nanmax(x))
# --> 208         mn, mx = [mi + 0.0 for mi in rng]
#     209
# ...

# %%
int('5-20'.split('-')[1])
# Out:
# 20

# %%
"5-20".split('-')[0]
# Out:
# '5'

# %%
int('120cm'.split('cm')[0])
# Out:
# 120

# %%
sdf1 = df1["Height"]
sdf1
df2 = sdf1.str.split("-", expand=True)
sdf1.str.split("-")
for i in range(len(sdf1)):
    if 'cm' not in sdf1[i]:
        sdf1[i]=int(sdf1[i].split('-')[0])+int(sdf1[i].split('-')[1])
    else:
        sdf1[i]=int(sdf1[i].replace('cm',''))
        print(sdf1[i])
# Out:
# c:\users\pablo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# c:\users\pablo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 208
# 185
# 185
# 208
# 208
# 175
# 175
# 203
# 191
# 191
# 191
# 191
# 206
# 191
# 191
# 206
# 201
# 201
# 201
# 203
# 203
# 208
# 203
# 203
# 203
# 203
# 203
# 203
# 211
# 206
# 211
# 203
# 211
# 221
# 213
# 208
# 213
# 213
# 206
# 193
# 193
# 193
# 191
# 191
# 191
# 191
# 201
# 201
# 211
# 211
# 196
# 196
# 196
# ...
